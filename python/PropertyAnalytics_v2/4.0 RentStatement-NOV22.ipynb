# %%
from mt_rent_statement import *

# %% [markdown]
# ### Load data

# %%
start='2022-11-01'
end='2022-11-30'
dfT=load_tenancies('all_tenancies.xls')
dfAll=load_data(start,end)
dfAll.head(3)
# Out:
# WARNING *** file size (102054) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Reading file: E:\dtuklaptop\e\Users\Mat\python\data\property\checked\NOV2022_codedAndCategorised.xlsx
# E:\dtuklaptop\e\Users\Mat\python\14. property\PropertyAnalytics_v2\mt_rent_statement.py:163: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   dfAll=pd.concat([dfAll,dfTemp])
#                       Account  Amount   Subcategory  \
# 2022-11-01  20-74-09 60458872 -220.72  Direct Debit
# 2022-11-01  20-53-97 30728691 -722.99  Direct Debit
# 2022-11-01  20-53-97 30728691 -332.44  Direct Debit
#
#                                                    Memo   Property  \
# 2022-11-01  CHL HOME LOAN         CHL00002/907372200 DD   F2169FAW
# 2022-11-01  NRAM                  NRD00001/631516204 DD     23CHAM
# 2022-11-01  TOPAZ FIN JASPER      PRU00010/190859005 DD  F31618ALH
#
#            Description       Cat Subcat
# 2022-11-01         NaN  Mortgage    NaN
# 2022-11-01         NaN  Mortgage    NaN
# 2022-11-01         NaN  Mortgage    NaN

# %% [markdown]
# ### Rent Statement

# %%
paidinadvancelist = ['Peter Gradon (28/02/2018)']  # November
inarrearslist = ['Mark Williams (25/09/2019)']
dfRs=get_rent_statement(dfAll, dfT, start, end, inarrearslist, paidinadvancelist)
dfRs=dfRs.round(0)
#dfRs.sort_values(by=['Net'], ascending=False).style.apply(custom_style, axis=1)
#dfRs.sort_values(by=['Bills'], ascending=True).style.apply(custom_style, axis=1)
dfRs.style.apply(custom_style, axis=1)
# Out:
# <style  type="text/css" >
#     #T_94184394_8ea2_11ed_a011_fcaa147063aarow0_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow0_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow0_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow0_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow0_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow0_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow0_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow1_col0 {
#             background-color:  red;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow1_col1 {
#             background-color:  red;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow1_col2 {
#             background-color:  red;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow1_col3 {
#             background-color:  red;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow1_col4 {
#             background-color:  red;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow1_col5 {
#             background-color:  red;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow1_col6 {
#             background-color:  red;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow2_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow2_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow2_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow2_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow2_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow2_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow2_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow3_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow3_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow3_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow3_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow3_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow3_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow3_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow4_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow4_col1 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow4_col2 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow4_col3 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow4_col4 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow4_col5 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow4_col6 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow5_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow5_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow5_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow5_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow5_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow5_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow5_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow6_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow6_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow6_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow6_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147063aarow6_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_94184394_8ea2_11ed_a011_fcaa147

# %% [markdown]
# Notes:
# - Susheel move out
# - 5 empty -> F1, 321, F3 321, F4 321, F8 46, F20 46
# - Mark Williams didn't pay
# - Graddon paid 6 months advance in Sept to March - Gradon was served S13 rent increase
# - check rent increases in Dec for McIlwraith, England, Milligan

# %% [markdown]
# ### Income/Expenditure per Property

# %%
plot_income_expenditure_per_property(dfRs[:-1])

# %% [markdown]
# ### Net Income Per Property

# %%
plot_net_income(dfRs[:-1])

# %% [markdown]
# ### Accounts Check
# Check Drawings against expenses

# %%
dfAll[(dfAll.Cat=='RegularPayment')|(dfAll.Cat=='PersonalExpense')|(dfAll.Cat=='Hilltop')|(dfAll.Cat=='HMRCDD')|(dfAll.Cat=='Drawings')|(dfAll.Cat=='SchoolFee')].groupby(['Cat']).sum()
# Out:
#                   Amount
# Cat
# Drawings        -2400.00
# HMRCDD           -600.00
# Hilltop          -300.00
# PersonalExpense -3562.05
# RegularPayment  -1072.05
# SchoolFee       -5688.99

# %%
dfAll.groupby(['Account','Cat']).sum().style.apply(custom_style_accounts_cat, axis=1)
# Out:
# <style  type="text/css" >
#     #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow0_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow1_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow2_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow3_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow4_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow5_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow6_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow7_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow8_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow9_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow10_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow11_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow12_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow13_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow14_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow15_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow16_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow17_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow18_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow19_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow20_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow21_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow22_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow23_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow24_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow25_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow26_col0 {
#             background-color:  pink;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow27_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow28_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow29_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_95964e54_8ea2_11ed_9be3_fcaa147063aarow30_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }</style><table id="T_95964e54_8ea2_11ed_9be3_fcaa147063aa" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Amount</th>    </tr>    <tr>        <th class="index_name level0" >Account</th>        <th class="index_name level1" >Cat</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_95964e54_8ea2_11ed_9be3_fcaa147063aalevel0_row0" class="row_heading level0 row0" rowspan=8>20-53-97 30728691</th>
#                         <th id="T_95964e54_8ea2_11ed_9be3_fcaa147063aalevel1_row0" class="row_heading level1 row0" >Funds4040</th>
#                         <td id="T_95964e54_8ea2_11ed_9be3_fcaa147063aarow0_col0" class="data row0 col0" >-500</td>
#             </tr>
#             <tr>
#                                 <th id="T_95964e54_8ea2_11ed_9be3_fcaa147063aalevel1_row1" class="row_heading level1 row1" >Funds6045</th>
#                         <td id="T_95964e54_8ea2_11ed_9be3_fcaa147063aarow1_col0" class="data row1 col0" >-34965.6</td>
#             </tr>
#             <tr>
#                                 <th id="T_95964e54_8ea2_11ed_9be3_fcaa147063aalevel1_row2" class="row_heading level1 row2" >HMRCDD</th>
#                         <td id="T_95964e54_8ea2_11ed_9be3_fcaa147063aarow2_col0" class="data row2 col0" >-300</td>
#             </tr>
#             <tr>
#                                 <th id="T_95964e54_8ea2_11ed_9be3_fcaa147063aalevel1_row3" class="row_heading level1 row3" >Mortgage</th>
#                         <td id="T_95964e54_8ea2_11ed_9be3_fcaa147063aarow3_col0" class="data row3 col0" >-6014.63</td>
#             </tr>
#             <tr>
#                                 <th id="T_95964e54_8ea2_11ed_9be3_fcaa147063aalevel1_row4" class="row_heading level1 row4" >MortgageRefund</th>
#                         <td id="T_95964e54_8ea2_11ed_9be3_fcaa147063aarow4_col0" class="data row4 col0" >2294.39</td>
#             </tr>
#             <tr>
#                                 <th id="T_95964e54_8ea2_11ed_9be3_fcaa147063aalevel1_row5" class="row_heading level1 row5" >OurRent</th>
#                         <td id="T_95964e54_8ea2_11ed_9be3_fcaa147063aarow5_col0" class="data row5 col0" >524.1</td>
#             </tr>
#             <tr>
#                                 <th id="T_95964e54_8ea2_11ed_9be3_fcaa147063aalevel1_row6" class="row_heading level1 row6" >RegularPayment</th>
#                         <td id="T_95964e54_8ea2_11ed_9be3_fcaa147063aarow6_col0" class="data row6 col0" >-887.82</td>
#             </tr>
#             <tr>
#                                 <th id="T_95964e54_8ea2_11ed_9be3_fcaa147063aalevel1_row7" class="row_heading level1 row7" >SchoolFee

# %% [markdown]
# #### Mortgage check
# Check mortgages refunded from business account

# %%
dfMtg=dfAll[((dfAll.Cat=='Mortgage')|(dfAll.Cat=='MortgageRefund'))&(dfAll.Account!='60-83-71 00558156')].groupby(['Account','Cat']).Amount.sum()
dfMtg=dfMtg.reset_index().pivot('Account','Cat')
dfMtg.columns=dfMtg.columns.get_level_values(1)
if('MortgageRefund' not in dfMtg.columns):
    dfMtg['MortgageRefund']=0
dfMtg['Diff']=dfMtg.Mortgage + dfMtg.MortgageRefund
dfMtg
# Out:
# Cat                Mortgage  MortgageRefund     Diff
# Account
# 20-53-97 30728691  -6014.63         2294.39 -3720.24
# 20-74-09 60458872  -8551.23         6728.66 -1822.57

# %%
dfMtg['Diff'].sum()
# Out:
# -5542.810000000003

# %% [markdown]
# #### Rent check
# Rents going to wrong account

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='OurRent')]
# Out:
#                       Account  Amount     Subcategory  \
# 2022-11-07  20-53-97 30728691   285.0  Counter Credit
# 2022-11-10  20-53-97 30728691  -480.9    Bill Payment
# 2022-11-25  20-53-97 30728691   675.0  Standing Order
# 2022-11-28  20-53-97 30728691  -675.0    Bill Payment
# 2022-11-30  20-53-97 30728691   720.0  Counter Credit
#
#                                                    Memo    Property  \
# 2022-11-07   F23 4-6ALHAMBRA       SEQUENCE UK LIMI BGC    F2346ALH
# 2022-11-10  RSA CAPITAL LIMITE    16 16-18 JAN 2023 BBP  F161618ALH
# 2022-11-25  MR MICHAEL BETTS      FT11 12-14ALHAMBRA ST  F111214ALH
# 2022-11-28  RSA CAPITAL LIMITE    M BETTSRENT 111214 BB  F111618ALH
# 2022-11-30               M Williams            RENT BGC     196BKIN
#
#                Description      Cat Subcat
# 2022-11-07    Need to move  OurRent    NaN
# 2022-11-10  What was this?  OurRent    NaN
# 2022-11-25             NaN  OurRent    NaN
# 2022-11-28             NaN  OurRent    NaN
# 2022-11-30    Need to move  OurRent    NaN

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='OurRent')].groupby(['Cat']).sum()
# Out:
#          Amount
# Cat
# OurRent   524.1

# %% [markdown]
# #### Property expense check
# Property expenses and service charges taken from 3072 or 6045

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='PropertyExpense')]
# Out:
#                       Account  Amount     Subcategory  \
# 2022-11-11  20-74-09 60458872   -15.0  Standing Order
#
#                                             Memo Property Description  \
# 2022-11-11  SSE SOUTHERN ELECT    6882766014 STO   169FAW   Move over
#
#                         Cat Subcat
# 2022-11-11  PropertyExpense    NaN

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='PropertyExpense')].groupby(['Cat']).sum()
# Out:
#                  Amount
# Cat
# PropertyExpense   -15.0

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='ServiceCharge')]
# Out:
# Empty DataFrame
# Columns: [Account, Amount, Subcategory, Memo, Property, Description, Cat, Subcat]
# Index: []

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='ServiceCharge')].groupby(['Cat']).sum()
# Out:
# Empty DataFrame
# Columns: [Amount]
# Index: []

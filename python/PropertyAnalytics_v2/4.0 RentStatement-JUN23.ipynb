# %%
from mt_rent_statement import *

# %% [markdown]
# ### Load data

# %%
start='2023-06-01'
end='2023-06-30'
dfT=load_tenancies('all_tenancies.xls')
dfAll=load_data(start,end)
dfAll.head(3)
# Out:
# Reading file: E:\dtuklaptop\e\Users\Mat\python\data\property\checked\JUN2023_codedAndCategorised.xlsx
# E:\dtuklaptop\e\Users\Mat\python\14. property\PropertyAnalytics_v2\mt_rent_statement.py:163: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   dfAll=pd.concat([dfAll,dfTemp])
#                       Account  Amount     Subcategory  \
# 2023-06-01  20-74-09 60458872  141.00  Counter Credit
# 2023-06-01  20-53-97 30728691 -510.98    Direct Debit
# 2023-06-01  20-53-97 30728691 -553.54    Direct Debit
#
#                                                    Memo   Property  \
# 2023-06-01  BEALS ESTATE AGENT    FLAT 4321 LONDON R BG   F4321LON
# 2023-06-01     PLATFORM FUNDING      01050230313307 DDR  F61618ALH
# 2023-06-01     PLATFORM FUNDING      01050229961090 DDR   F2246ALH
#
#             Description        Cat Subcat
# 2023-06-01          NaN  BealsRent    NaN
# 2023-06-01          NaN   Mortgage    NaN
# 2023-06-01          NaN   Mortgage    NaN

# %% [markdown]
# ### Rent Statement

# %%
paidinadvancelist = ['Peter Gradon (28/02/2018)'] 
inarrearslist = ['Mark Williams (25/09/2019)']
dfRs=get_rent_statement(dfAll, dfT, start, end, inarrearslist, paidinadvancelist)
dfRs=dfRs.round(0)
#dfRs.sort_values(by=['Net'], ascending=False).style.apply(custom_style, axis=1)
#dfRs.sort_values(by=['Bills'], ascending=True).style.apply(custom_style, axis=1)
dfRs.style.apply(custom_style, axis=1)
# Out:
# <style  type="text/css" >
#     #T_eb53d314_3085_11ee_a883_4a225492749frow0_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow0_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow0_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow0_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow0_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow0_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow0_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow1_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow1_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow1_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow1_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow1_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow1_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow1_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow2_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow2_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow2_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow2_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow2_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow2_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow2_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow3_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow3_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow3_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow3_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow3_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow3_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow3_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow4_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow4_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow4_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow4_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow4_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow4_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow4_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow5_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow5_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow5_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow5_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow5_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow5_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow5_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow6_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow6_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow6_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow6_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_4a225492749frow6_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_eb53d314_3085_11ee_a883_

# %% [markdown]
# This month:
#
# - rate 4.5%

# %% [markdown]
# Notes:
# - Valverde evicted 26/01/23, Radzevics 13/12/22, Hinks 10/02/23, Austin 03/04/23
# - Mark Williams didn't pay Oct
# - Graddon paid 6 months advance in Sept to March - Gradon was served S13 rent increase and paid the difference in Jan 23
# - Ivana to check rent increases for:
#     - Parkinson
#     - Pedace
#     - Passmore
#     - Henson
# - F1 171 rent raised to £875 on 06/03/23
# - Plan to give S13 to Henson on 01/03/23
# - ** Need to refund Fratton roof payment in Jan

# %% [markdown]
# ### Income/Expenditure per Property

# %%
plot_income_expenditure_per_property(dfRs[:-1])

# %% [markdown]
# ### Net Income Per Property

# %%
plot_net_income(dfRs[:-1])

# %% [markdown]
# ### Accounts Check
# Check Drawings against expenses

# %%
dfAll[(dfAll.Cat=='RegularPayment')|(dfAll.Cat=='PersonalExpense')|(dfAll.Cat=='Hilltop')|(dfAll.Cat=='HMRCDD')|(dfAll.Cat=='Drawings')|(dfAll.Cat=='SchoolFee')].groupby(['Cat']).sum()
# Out:
#                   Amount  Description
# Cat
# Drawings           -4.99          0.0
# HMRCDD           -300.00          0.0
# Hilltop          -300.00          0.0
# PersonalExpense -2066.36          0.0
# RegularPayment   -944.15          0.0
# SchoolFee       -5677.51          0.0

# %%
dfAll.groupby(['Account','Cat']).sum().style.apply(custom_style_accounts_cat, axis=1)
# Out:
# <style  type="text/css" >
#     #T_edcc0c1c_3085_11ee_becd_4a225492749frow0_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow0_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow1_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow1_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow2_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow2_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow3_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow3_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow4_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow4_col1 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow5_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow5_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow6_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow6_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow7_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow7_col1 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow8_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow8_col1 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow9_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow9_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow10_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow10_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow11_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow11_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow12_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow12_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow13_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow13_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow14_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow14_col1 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow15_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow15_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow16_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow16_col1 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow17_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow17_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow18_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow18_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow19_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow19_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow20_col0 {
#             background-color:  pink;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow20_col1 {
#             background-color:  pink;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow21_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow21_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow22_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow22_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_edcc0c1c_3085_11ee_becd_4a225492749frow23_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;

# %% [markdown]
# #### Mortgage check
# Check mortgages refunded from business account

# %%
dfMtg=dfAll[((dfAll.Cat=='Mortgage')|(dfAll.Cat=='MortgageRefund'))&(dfAll.Account!='60-83-71 00558156')].groupby(['Account','Cat']).Amount.sum()
dfMtg=dfMtg.reset_index().pivot('Account','Cat')
dfMtg.columns=dfMtg.columns.get_level_values(1)
if('MortgageRefund' not in dfMtg.columns):
    dfMtg['MortgageRefund']=0
dfMtg['Diff']=dfMtg.Mortgage + dfMtg.MortgageRefund
dfMtg
# Out:
# Cat                Mortgage  MortgageRefund      Diff
# Account
# 20-53-97 30728691 -22496.64               0 -22496.64

# %%
dfMtg['Diff'].sum()
# Out:
# -22496.640000000003

# %% [markdown]
# #### Rent check
# Rents going to wrong account

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='OurRent')]
# Out:
# Empty DataFrame
# Columns: [Account, Amount, Subcategory, Memo, Property, Description, Cat, Subcat]
# Index: []

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='OurRent')].groupby(['Cat']).sum()
# Out:
# Empty DataFrame
# Columns: [Amount, Description]
# Index: []

# %% [markdown]
# #### Property expense check
# Property expenses and service charges taken from 3072 or 6045

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='PropertyExpense')]
# Out:
#                       Account  Amount     Subcategory  \
# 2023-06-23  20-74-09 60458872   -15.0  Standing Order
#
#                                             Memo Property  Description  \
# 2023-06-23  SSE SOUTHERN ELECT    6882766014 STO   169FAW          NaN
#
#                         Cat Subcat
# 2023-06-23  PropertyExpense    NaN

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='PropertyExpense')].groupby(['Cat']).sum()
# Out:
#                  Amount  Description
# Cat
# PropertyExpense   -15.0          0.0

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='ServiceCharge')]
# Out:
# Empty DataFrame
# Columns: [Account, Amount, Subcategory, Memo, Property, Description, Cat, Subcat]
# Index: []

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='ServiceCharge')].groupby(['Cat']).sum()
# Out:
# Empty DataFrame
# Columns: [Amount, Description]
# Index: []

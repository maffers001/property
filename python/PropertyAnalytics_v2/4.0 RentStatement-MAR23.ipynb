# %%
from mt_rent_statement import *

# %% [markdown]
# ### Load data

# %%
start='2023-03-01'
end='2023-03-31'
dfT=load_tenancies('all_tenancies.xls')
dfAll=load_data(start,end)
dfAll.head(3)
# Out:
# WARNING *** file size (103480) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Reading file: E:\dtuklaptop\e\Users\Mat\python\data\property\checked\MAR2023_codedAndCategorised.xlsx
# E:\dtuklaptop\e\Users\Mat\python\14. property\PropertyAnalytics_v2\mt_rent_statement.py:163: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   dfAll=pd.concat([dfAll,dfTemp])
#                       Account  Amount     Subcategory  \
# 2023-03-01  20-74-09 60458872  -50.00  Standing Order
# 2023-03-01  20-53-97 30728691 -299.16    Direct Debit
# 2023-03-01  20-53-97 30728691 -300.91    Direct Debit
#
#                                                    Memo  Property Description  \
# 2023-03-01     NATIONWIDE            0604/229172770 STO       NaN         NaN
# 2023-03-01  CHL HOME LOAN         CHL00002/907372200 DD  F2169FAW         NaN
# 2023-03-01  CHL HOME LOAN         CHL00002/907371904 DD  F3321LON         NaN
#
#                        Cat Subcat
# 2023-03-01  RegularPayment    NaN
# 2023-03-01        Mortgage    NaN
# 2023-03-01        Mortgage    NaN

# %% [markdown]
# ### Rent Statement

# %%
paidinadvancelist = ['Peter Gradon (28/02/2018)'] 
inarrearslist = ['Mark Williams (25/09/2019)']
dfRs=get_rent_statement(dfAll, dfT, start, end, inarrearslist, paidinadvancelist)
dfRs=dfRs.round(0)
#dfRs.sort_values(by=['Net'], ascending=False).style.apply(custom_style, axis=1)
#dfRs.sort_values(by=['Bills'], ascending=True).style.apply(custom_style, axis=1)
dfRs.style.apply(custom_style, axis=1)
# Out:
# <style  type="text/css" >
#     #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow0_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow0_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow0_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow0_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow0_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow0_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow0_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow1_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow1_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow1_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow1_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow1_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow1_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow1_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow2_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow2_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow2_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow2_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow2_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow2_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow2_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow3_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow3_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow3_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow3_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow3_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow3_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow3_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow4_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow4_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow4_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow4_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow4_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow4_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow4_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow5_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow5_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow5_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow5_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow5_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow5_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow5_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow6_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow6_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow6_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow6_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_4a225492749frow6_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_07b1fc92_ff9c_11ed_b5fa_

# %% [markdown]
# This month:
#
# - rate 4.0%

# %% [markdown]
# Notes:
# - Valverde evicted 26/01/23, Radzevics 13/12/22, Hinks 10/02/23, Austin 03/04/23
# - Mark Williams didn't pay Oct
# - Graddon paid 6 months advance in Sept to March - Gradon was served S13 rent increase and paid the difference in Jan 23
# - Ivana to check rent increases for:
#     - Parkinson
#     - Pedace
#     - Passmore
#     - Henson
# - F1 171 rent raised to £875 on 06/03/23
# - Plan to give S13 to Henson on 01/03/23
# - ** Need to refund Fratton roof payment in Jan

# %% [markdown]
# ### Income/Expenditure per Property

# %%
plot_income_expenditure_per_property(dfRs[:-1])

# %% [markdown]
# ### Net Income Per Property

# %%
plot_net_income(dfRs[:-1])

# %% [markdown]
# ### Accounts Check
# Check Drawings against expenses

# %%
dfAll[(dfAll.Cat=='RegularPayment')|(dfAll.Cat=='PersonalExpense')|(dfAll.Cat=='Hilltop')|(dfAll.Cat=='HMRCDD')|(dfAll.Cat=='Drawings')|(dfAll.Cat=='SchoolFee')].groupby(['Cat']).sum()
# Out:
#                   Amount
# Cat
# Drawings           -1.00
# HMRCDD           -868.33
# Hilltop          -300.00
# PersonalExpense -4001.97
# RegularPayment   -940.38
# SchoolFee       -5684.78

# %%
dfAll.groupby(['Account','Cat']).sum().style.apply(custom_style_accounts_cat, axis=1)
# Out:
# <style  type="text/css" >
#     #T_09383754_ff9c_11ed_b45a_4a225492749frow0_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_09383754_ff9c_11ed_b45a_4a225492749frow1_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_09383754_ff9c_11ed_b45a_4a225492749frow2_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_09383754_ff9c_11ed_b45a_4a225492749frow3_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_09383754_ff9c_11ed_b45a_4a225492749frow4_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_09383754_ff9c_11ed_b45a_4a225492749frow5_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_09383754_ff9c_11ed_b45a_4a225492749frow6_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_09383754_ff9c_11ed_b45a_4a225492749frow7_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_09383754_ff9c_11ed_b45a_4a225492749frow8_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_09383754_ff9c_11ed_b45a_4a225492749frow9_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_09383754_ff9c_11ed_b45a_4a225492749frow10_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_09383754_ff9c_11ed_b45a_4a225492749frow11_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_09383754_ff9c_11ed_b45a_4a225492749frow12_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_09383754_ff9c_11ed_b45a_4a225492749frow13_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_09383754_ff9c_11ed_b45a_4a225492749frow14_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_09383754_ff9c_11ed_b45a_4a225492749frow15_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_09383754_ff9c_11ed_b45a_4a225492749frow16_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_09383754_ff9c_11ed_b45a_4a225492749frow17_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_09383754_ff9c_11ed_b45a_4a225492749frow18_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_09383754_ff9c_11ed_b45a_4a225492749frow19_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_09383754_ff9c_11ed_b45a_4a225492749frow20_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_09383754_ff9c_11ed_b45a_4a225492749frow21_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_09383754_ff9c_11ed_b45a_4a225492749frow22_col0 {
#             background-color:  pink;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_09383754_ff9c_11ed_b45a_4a225492749frow23_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_09383754_ff9c_11ed_b45a_4a225492749frow24_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_09383754_ff9c_11ed_b45a_4a225492749frow25_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_09383754_ff9c_11ed_b45a_4a225492749frow26_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_09383754_ff9c_11ed_b45a_4a225492749frow27_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_09383754_ff9c_11ed_b45a_4a225492749frow28_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }</style><table id="T_09383754_ff9c_11ed_b45a_4a225492749f" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Amount</th>    </tr>    <tr>        <th class="index_name level0" >Account</th>        <th class="index_name level1" >Cat</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_09383754_ff9c_11ed_b45a_4a225492749flevel0_row0" class="row_heading level0 row0" rowspan=7>20-53-97 30728691</th>
#                         <th id="T_09383754_ff9c_11ed_b45a_4a225492749flevel1_row0" class="row_heading level1 row0" >Deposit</th>
#                         <td id="T_09383754_ff9c_11ed_b45a_4a225492749frow0_col0" class="data row0 col0" >156.6</td>
#             </tr>
#             <tr>
#                                 <th id="T_09383754_ff9c_11ed_b45a_4a225492749flevel1_row1" class="row_heading level1 row1" >HMRCDD</th>
#                         <td id="T_09383754_ff9c_11ed_b45a_4a225492749frow1_col0" class="data row1 col0" >-300</td>
#             </tr>
#             <tr>
#                                 <th id="T_09383754_ff9c_11ed_b45a_4a225492749flevel1_row2" class="row_heading level1 row2" >Mortgage</th>
#                         <td id="T_09383754_ff9c_11ed_b45a_4a225492749frow2_col0" class="data row2 col0" >-20675.4</td>
#             </tr>
#             <tr>
#                                 <th id="T_09383754_ff9c_11ed_b45a_4a225492749flevel1_row3" class="row_heading level1 row3" >OtherExpense</th>
#                         <td id="T_09383754_ff9c_11ed_b45a_4a225492749frow3_col0" class="data row3 col0" >-38.49</td>
#             </tr>
#             <tr>
#                                 <th id="T_09383754_ff9c_11ed_b45a_4a225492749flevel1_row4" class="row_heading level1 row4" >OtherIncome</th>
#                         <td id="T_09383754_ff9c_11ed_b45a_4a225492749frow4_col0" class="data row4 col0" >21486.5</td>
#             </tr>
#             <tr>
#                                 <th id="T_09383754_ff9c_11ed_b45a_4a225492749flevel1_row5" class="row_heading level1 row5" >OurRent</th>
#                         <td id="T_09383754_ff9c_11ed_b45a_4a225492749frow5_col0" class="data row5 col0" >820</td>
#             </tr>
#             <tr>
#                                 <th id="T_09383754_ff9c_11ed_b45a_4a225492749flevel1_row6" class="row_heading level1 row6" >RegularPayment</th>
#                         <td id="T_09383754_ff9c_11ed_b45a_4a225492749frow6_col0" class="data row6 col0" >-629.17</td>
#             </tr>
#             <tr>
#                         <th id="T_09383754_ff9c_11ed_b45a_4a225492749flevel0_row7" class="row_heading level0 row7" rowspan=3>20-74-09 40406538</th>
#                         <th id="T_09383754_ff9c_11ed_b45a_4a225492749flevel1_row7" class="row_heading level1 row7" >OtherIncome</th>
#                         <td id="T_09383754_ff9c_11ed_b45a_4a225492749frow7_col0" class="data row7 col0" >3001</td>
#             </tr>
#             <tr>
#                                 <th id="T_0938

# %% [markdown]
# #### Mortgage check
# Check mortgages refunded from business account

# %%
dfMtg=dfAll[((dfAll.Cat=='Mortgage')|(dfAll.Cat=='MortgageRefund'))&(dfAll.Account!='60-83-71 00558156')].groupby(['Account','Cat']).Amount.sum()
dfMtg=dfMtg.reset_index().pivot('Account','Cat')
dfMtg.columns=dfMtg.columns.get_level_values(1)
if('MortgageRefund' not in dfMtg.columns):
    dfMtg['MortgageRefund']=0
dfMtg['Diff']=dfMtg.Mortgage + dfMtg.MortgageRefund
dfMtg
# Out:
# Cat                Mortgage  MortgageRefund      Diff
# Account
# 20-53-97 30728691 -20675.42               0 -20675.42

# %%
dfMtg['Diff'].sum()
# Out:
# -20675.419999999995

# %% [markdown]
# #### Rent check
# Rents going to wrong account

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='OurRent')]
# Out:
#                       Account  Amount     Subcategory  \
# 2023-03-31  20-53-97 30728691   820.0  Counter Credit
#
#                                       Memo Property Description      Cat  \
# 2023-03-31  M Williams            RENT BGC  196BKIN         NaN  OurRent
#
#            Subcat
# 2023-03-31    NaN

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='OurRent')].groupby(['Cat']).sum()
# Out:
#          Amount
# Cat
# OurRent   820.0

# %% [markdown]
# #### Property expense check
# Property expenses and service charges taken from 3072 or 6045

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='PropertyExpense')]
# Out:
#                       Account  Amount     Subcategory  \
# 2023-03-03  20-74-09 60458872   -15.0  Standing Order
# 2023-03-31  20-74-09 60458872   -15.0  Standing Order
#
#                                             Memo Property Description  \
# 2023-03-03  SSE SOUTHERN ELECT    6882766014 STO   169FAW         NaN
# 2023-03-31  SSE SOUTHERN ELECT    6882766014 STO   169FAW         NaN
#
#                         Cat Subcat
# 2023-03-03  PropertyExpense    NaN
# 2023-03-31  PropertyExpense    NaN

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='PropertyExpense')].groupby(['Cat']).sum()
# Out:
#                  Amount
# Cat
# PropertyExpense   -30.0

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='ServiceCharge')]
# Out:
# Empty DataFrame
# Columns: [Account, Amount, Subcategory, Memo, Property, Description, Cat, Subcat]
# Index: []

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='ServiceCharge')].groupby(['Cat']).sum()
# Out:
# Empty DataFrame
# Columns: [Amount]
# Index: []

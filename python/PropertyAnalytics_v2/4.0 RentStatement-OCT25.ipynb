# %%
from mt_rent_statement import *

# %% [markdown]
# ### Load data

# %%
start='2025-10-01'
end='2025-10-31'
dfT=load_tenancies('all_tenancies.xls')
dfAll=load_data(start,end)
dfAll.head(3)
# Out:
# WARNING *** file size (106483) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Reading file: J://My Drive//NAS//My Documents//Business//Property//Statements//working//python//data//property//checked//OCT2025_codedAndCategorised.xlsx
#                       Account   Amount                Subcategory  \
# 2025-10-01  20-74-09 60458872  3000.00             Counter Credit
# 2025-10-01  20-74-09 40406538    28.35              Card Purchase
# 2025-10-01  20-74-09 40406538   -15.90  Contactless Card Purchase
#
#                                            Memo Property  Description  \
# 2025-10-01         M Tucker              SF BGC      NaN          NaN
# 2025-10-01  trainline             ON 29 SEP BCC      NaN          NaN
# 2025-10-01  MARKS&SPENCER PLC     ON 30 SEP CLP      NaN          NaN
#
#                         Cat Subcat
# 2025-10-01        MTPayment    NaN
# 2025-10-01  PersonalExpense  Other
# 2025-10-01  PersonalExpense    M&S

# %% [markdown]
# ### Rent Statement

# %%
paidinadvancelist = ['Peter Gradon (28/02/2018)','Camilla Bailey & Michael Gregson (31/08/2023)','Charlotte McLellan-Campbell & Jose Gongora Oliva (10/09/2023)']
inarrearslist = ['Mark Williams (25/09/2019)']
dfRs=get_rent_statement(dfAll, dfT, start, end, inarrearslist, paidinadvancelist)
dfRs=dfRs.round(0)
#dfRs.sort_values(by=['Net'], ascending=False).style.apply(custom_style, axis=1)
#dfRs.sort_values(by=['Bills'], ascending=True).style.apply(custom_style, axis=1)
#dfRs.style.apply(custom_style, axis=1)
num_cols = dfRs.select_dtypes(include=["number"]).columns
dfRs.style.format({c: "{:.0f}" for c in num_cols}).apply(custom_style, axis=1)
# Out:
# <style  type="text/css" >
# #T_bd38e012_e635_11f0_b794_580205fb330brow0_col0,#T_bd38e012_e635_11f0_b794_580205fb330brow0_col1,#T_bd38e012_e635_11f0_b794_580205fb330brow0_col2,#T_bd38e012_e635_11f0_b794_580205fb330brow0_col3,#T_bd38e012_e635_11f0_b794_580205fb330brow0_col4,#T_bd38e012_e635_11f0_b794_580205fb330brow0_col5,#T_bd38e012_e635_11f0_b794_580205fb330brow0_col6,#T_bd38e012_e635_11f0_b794_580205fb330brow1_col0,#T_bd38e012_e635_11f0_b794_580205fb330brow1_col1,#T_bd38e012_e635_11f0_b794_580205fb330brow1_col2,#T_bd38e012_e635_11f0_b794_580205fb330brow1_col3,#T_bd38e012_e635_11f0_b794_580205fb330brow1_col4,#T_bd38e012_e635_11f0_b794_580205fb330brow1_col5,#T_bd38e012_e635_11f0_b794_580205fb330brow1_col6,#T_bd38e012_e635_11f0_b794_580205fb330brow2_col0,#T_bd38e012_e635_11f0_b794_580205fb330brow2_col1,#T_bd38e012_e635_11f0_b794_580205fb330brow2_col2,#T_bd38e012_e635_11f0_b794_580205fb330brow2_col3,#T_bd38e012_e635_11f0_b794_580205fb330brow2_col4,#T_bd38e012_e635_11f0_b794_580205fb330brow2_col5,#T_bd38e012_e635_11f0_b794_580205fb330brow2_col6,#T_bd38e012_e635_11f0_b794_580205fb330brow3_col0,#T_bd38e012_e635_11f0_b794_580205fb330brow3_col1,#T_bd38e012_e635_11f0_b794_580205fb330brow3_col2,#T_bd38e012_e635_11f0_b794_580205fb330brow3_col3,#T_bd38e012_e635_11f0_b794_580205fb330brow3_col4,#T_bd38e012_e635_11f0_b794_580205fb330brow3_col5,#T_bd38e012_e635_11f0_b794_580205fb330brow3_col6,#T_bd38e012_e635_11f0_b794_580205fb330brow4_col0,#T_bd38e012_e635_11f0_b794_580205fb330brow4_col1,#T_bd38e012_e635_11f0_b794_580205fb330brow4_col2,#T_bd38e012_e635_11f0_b794_580205fb330brow4_col3,#T_bd38e012_e635_11f0_b794_580205fb330brow4_col4,#T_bd38e012_e635_11f0_b794_580205fb330brow4_col5,#T_bd38e012_e635_11f0_b794_580205fb330brow4_col6,#T_bd38e012_e635_11f0_b794_580205fb330brow5_col0,#T_bd38e012_e635_11f0_b794_580205fb330brow5_col1,#T_bd38e012_e635_11f0_b794_580205fb330brow5_col2,#T_bd38e012_e635_11f0_b794_580205fb330brow5_col3,#T_bd38e012_e635_11f0_b794_580205fb330brow5_col4,#T_bd38e012_e635_11f0_b794_580205fb330brow5_col5,#T_bd38e012_e635_11f0_b794_580205fb330brow5_col6,#T_bd38e012_e635_11f0_b794_580205fb330brow7_col0,#T_bd38e012_e635_11f0_b794_580205fb330brow7_col1,#T_bd38e012_e635_11f0_b794_580205fb330brow7_col2,#T_bd38e012_e635_11f0_b794_580205fb330brow7_col3,#T_bd38e012_e635_11f0_b794_580205fb330brow7_col4,#T_bd38e012_e635_11f0_b794_580205fb330brow7_col5,#T_bd38e012_e635_11f0_b794_580205fb330brow7_col6,#T_bd38e012_e635_11f0_b794_580205fb330brow8_col0,#T_bd38e012_e635_11f0_b794_580205fb330brow8_col1,#T_bd38e012_e635_11f0_b794_580205fb330brow8_col2,#T_bd38e012_e635_11f0_b794_580205fb330brow8_col3,#T_bd38e012_e635_11f0_b794_580205fb330brow8_col4,#T_bd38e012_e635_11f0_b794_580205fb330brow8_col5,#T_bd38e012_e635_11f0_b794_580205fb330brow8_col6,#T_bd38e012_e635_11f0_b794_580205fb330brow9_col0,#T_bd38e012_e635_11f0_b794_580205fb330brow9_col1,#T_bd38e012_e635_11f0_b794_580205fb330brow9_col2,#T_bd38e012_e635_11f0_b794_580205fb330brow9_col3,#T_bd38e012_e635_11f0_b794_580205fb330brow9_col4,#T_bd38e012_e635_11f0_b794_580205fb330brow9_col5,#T_bd38e012_e635_11f0_b794_580205fb330brow9_col6,#T_bd38e012_e635_11f0_b794_580205fb330brow11_col0,#T_bd38e012_e635_11f0_b794_580205fb330brow11_col1,#T_bd38e012_e635_11f0_b794_580205fb330brow11_col2,#T_bd38e012_e635_11f0_b794_580205fb330brow11_col3,#T_bd38e012_e635_11f0_b794_580205fb330brow11_col4,#T_bd38e012_e635_11f0_b794_580205fb330brow11_col5,#T_bd38e012_e635_11f0_b794_580205fb330brow11_col6,#T_bd38e012_e635_11f0_b794_580205fb330brow12_col0,#T_bd38e012_e635_11f0_b794_580205fb330brow12_col1,#T_bd38e012_e635_11f0_b794_580205fb330brow12_col2,#T_bd38e012_e635_11f0_b794_580205fb330brow12_col3,#T_bd38e012_e635_11f0_b794_580205fb330brow12_col4,#T_bd38e012_e635_11f0_b794_580205fb330brow12_col5,#T_bd38e012_e635_11f0_b794_580205fb330brow12_col6,#T_bd38e012_e635_11f0_b794_580205fb330brow13_col0,#T_bd38e012_e635_11f0_b794_580205fb330brow13_col1,#T_bd38e012_e635_11f0_b794_580205fb330brow13_col2,#T_bd38e012_e635_11f0_b794_580205fb330brow13_col3,#T_bd38e012_e ...

# %% [raw]
# This month:
# - Susan Parkinson moved out
# - check Samuel Parkinson rent
# - Milligan died
# - F2 321 Cirprian is moving out on 25/01/24, he tried not to pay his last payment but his girlfriend paid
#
# Last month:
# - F3 321 Holman & Wolfe move in
# - F1 169 Susan Parkinson not paid
# - there were one off insurance expenses of £1355
# - no revenue received for 7 flats (1 non payer, 3 empties, 1 moving in, 2 paid in advance) and partial payment for 1
# - Parkinson, Brett underpayment
#
# Last month was low on revenue because 4 tenants paid in advance (Graddon, Fyles, Gregson, Oliva) and 3 moved out (Betts, McIllwraith, Gradon), 1 in arrears.
#
# This month similar revenue, 3 empty, 1 not paid, 2 paid in advance, 3 underpayments.
#
# TODO:
# - update move in/outs
# - Mark Williams didn't pay Oct 22
# - Ivana to check rent increases for Pedace, England, Yates, Passmore
# - Check Brett, Milligan & Passmore arrears
# - Brett rent
# - increase shop

# %% [markdown]
# Notes:
# - F1 321 Chowdhury moved in day after Soumya Xaviour moved out, there were no Fox & Sons fees for this tenant
# - F17 46 Sophie Bedford moved out end of July, Camilla Bailey & Michael Gregson move in 31/08/23
#     - in September they paid 6 months in advance to 28/02/23
# - 23B Shyni Bijumon & Bijumon Varghese moved in 03/09/23, there were no Fox & Sons fees for this tenant
# - 23C Ancy Mathews & Mathews Jose moved in 08/10/23, there were no Fox & Sons fees for this tenant
# - F7 8 Ben Kendall & Gabriella Nouvet-Aruaz moved in 08/09/23
# - F22 46 Charlotte McLellan-Campbell and Jose Gongora Oliva moved in on 10/09/23
#     - in October they paid 6 months in advance to 19/04/23
# - F3 321 Shubi Agarwal is moving out 27/12/23 - she asked to move out a before end of tenancy which was agreed to when we found new tenants (some found for 28/12/23)
# - F11 1214 Betts died on 5th November, he paid to 25/11/23
# - F14 1214 McIlwraith moved out 11/11/23
# - F16 1618 Gradon was given notice because he had a guy living with him who was pissing on doorstep, he moved out 18/11/23. He had paid in advance, there was £2k to pay him back and some from Beals
#
# Remarks:
# - each 0.25% increase in rates causes an increase in costs of £750 - ideally we need rates back at 4.5% to pay £22500 p/m
# - find out what happens when a business loans money to another and it is not repaid - ask Chatgpt
# - things should improve in March - by then hopefully empties rented, paid in advance start to pay again in March

# %% [markdown]
# ### Income/Expenditure per Property

# %%
plot_income_expenditure_per_property(dfRs[:-1])

# %% [markdown]
# ### Net Income Per Property

# %%
plot_net_income(dfRs[:-1])

# %% [markdown]
# ### Accounts Check
# Check Drawings against expenses

# %%
dfAll[(dfAll.Cat=='RegularPayment')|(dfAll.Cat=='PersonalExpense')|(dfAll.Cat=='Hilltop')|(dfAll.Cat=='HMRCDD')|(dfAll.Cat=='Drawings')|(dfAll.Cat=='SchoolFee')].groupby(['Cat']).sum()
# Out:
#                   Amount  Description
# Cat
# Hilltop          -300.00          0.0
# PersonalExpense -5804.34          0.0
# RegularPayment  -1250.66          0.0
# SchoolFee       -2887.12          0.0

# %%
dfAll.groupby(['Account','Cat']).sum().style.apply(custom_style_accounts_cat, axis=1)
# Out:
# <style  type="text/css" >
# #T_d0354e58_e5b8_11f0_80c0_580205fb330brow0_col0,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow0_col1,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow1_col0,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow1_col1,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow2_col0,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow2_col1,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow5_col0,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow5_col1,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow6_col0,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow6_col1,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow7_col0,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow7_col1,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow10_col0,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow10_col1,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow11_col0,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow11_col1,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow12_col0,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow12_col1,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow14_col0,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow14_col1,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow16_col0,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow16_col1,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow17_col0,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow17_col1,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow18_col0,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow18_col1,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow19_col0,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow19_col1,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow21_col0,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow21_col1,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow22_col0,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow22_col1,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow24_col0,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow24_col1{
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }#T_d0354e58_e5b8_11f0_80c0_580205fb330brow3_col0,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow3_col1,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow4_col0,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow4_col1,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow8_col0,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow8_col1,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow9_col0,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow9_col1,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow13_col0,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow13_col1,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow15_col0,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow15_col1,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow20_col0,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow20_col1,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow23_col0,#T_d0354e58_e5b8_11f0_80c0_580205fb330brow23_col1{
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }</style><table id="T_d0354e58_e5b8_11f0_80c0_580205fb330b" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Amount</th>        <th class="col_heading level0 col1" >Description</th>    </tr>    <tr>        <th class="index_name level0" >Account</th>        <th class="index_name level1" >Cat</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d0354e58_e5b8_11f0_80c0_580205fb330blevel0_row0" class="row_heading level0 row0" rowspan=5>20-53-97 30728691</th>
#                         <th id="T_d0354e58_e5b8_11f0_80c0_580205fb330blevel1_row0" class="row_heading level1 row0" >Interbank</th>
#                         <td id="T_d0354e58_e5b8_11f0_80c0_580205fb330brow0_col0" class="data row0 col0" >22422.030000</td>
#                         <td id="T_d0354e58_e5b8_11f0_80c0_580205fb330brow0_col1" class="data row0 col1" >0.000000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d0354e58_e5b8_11f0_80c0_580205fb330blevel1_row1" class="row_heading level1 row1" >Mortgage</th>
#                         <td id="T_d0354e58_e5b8_11f0_80c0_580205fb330brow1_col0" class="data row1 col0" >-20874.400000</td>
#                         <td id="T_d0354e58_e5b8_11f0_80c0_580205fb330brow1_col1" class="data row1 col1" >0.000000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d0354e58_e5b8_11f0_80c0_580205fb330blevel1_row2" class="row_heading level1 row2" >OtherExpense</th>
#                         <td id="T_d0354e58_e5b8_11f0_80c0_580205fb330brow2_col0" class="data row2 col0" >-6.370000</td>
#                         <td id="T_d0354e58_e5b8_11f0_80c0_580205fb330brow2_col1" class="data row2 col1" >0.000000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d0354e58_e5b8_11f0_80c0_580205fb330blevel1_row3" class="row_heading level1 row3" >PersonalExpense</th>
#                         <td id="T_d0354e58_e5b8_11f0_80c0_580205fb330brow3_col0" class="data row3 col0" >-38.000000</td>
#                         <td id="T_d0354e58_e5b8_11f0_80c0_580205fb330brow3_col1" class="data row3 col1" >0.000000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d0354e58_e5b8_11f0_80c0_580205fb330blevel1_row4" class="row_heading level1 row4" >RegularPayment</th>
#                         <td id="T_d0354e58_e5b8_11f0_80c0_580205fb330brow4_col0" class="data row4 col0" >-612.920000</td>
#                         <td id="T_d0354e58_e5b8_11f0_80c0_580205fb330brow4_col1" class="data row4 col1" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_d0354e58_e5b8_11f0_80c0_580205fb330blevel0_row5" class="row_heading level0 row5" rowspan=5>20-74-09 40406538</th>
#                         <th id="T_d0354e58_e5b8_11f0_80c0_580205fb330blevel1_row5" class="row_heading level1 row5" >Interbank</th>
#                         <td id="T_d0354e58_e5b8_11f0_80c0_580205fb330brow5_col0" class="data row5 col0" >750.000000</td>
#                         <td id="T_d0354e58_e5b8_11f0_80c0_580205fb330brow5_col1" class="data row5 col1" >0.000000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d0354e58_e5b8_11f0_80c0_580205fb330blevel1_row6" class="row_heading level1 row6" >MTPayment</th>
#                         <td id="T_d0354e58_e5b8_11f0_80c0_580205fb330brow6_col0" class="data row6 col0" >300.000000</td>
#                         <td id="T_d0354e58_e5b8_11f0_80c0_580205fb330brow6_col1" class="data row6 col1" >0.000000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d0354e58_e5b8_11f0_80c0_580205fb330blevel1_row7" class="row_heading level1 row7" >OtherExpense</th>
#                         <td id="T_d0354e58_e5b8_11f0_80c0_580205fb330brow7_col0" class="data row7 col0" >-10.610000</td>
#                         <td id="T_d0354e58_e5b8_11f0_80c0_580205fb330brow7_col1" class="data row7 col1" >0.000000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d0354e58_e5b8_11f0_80c0_580205fb330blevel1_row8" class="row_heading level1 row8" >PersonalExpense</th>
#                         <td id="T_d0354e58_e5b8_11f0_80c0_580205fb330brow8_col0" class="data row8 col0" >-1078.140000</td>
#                         <td id="T_d0354e58_e5b8_11f0_80c0_580205fb330brow8_col1" class="data row8 col1" >0.000000</td>
#             </tr>
#             <tr>
#                                 <th id="T_d0354e58_e5b8_11f0_80c0_580205fb330blevel1_row9" class="row_heading level1 row9" >RegularPayment</th>
#                         <td id="T_d0354e58_e5b8_11f0_80c0_580205fb330brow9_col0" class="data row9 col0" >-8.000000</td>
#                         <td id="T_d0354e58_e5b8_11f0_80c0_580205fb330brow9_col1" class="data row9 col1" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_d0354e58_e5b8_11f0_80c0_580205fb330blevel0_row10" class="row_heading level0 row10" rowspan=7>20-74-09 60458872</th>
#                         <th id="T_d0354e58_e5b8_11f0_80c0_580205fb330blevel1_row10" class="row_heading level1 row10" >Hilltop</th>
#                         <td id="T_d0354e5

# %% [markdown]
# #### Mortgage check
# Check mortgages refunded from business account

# %%
dfMtg=dfAll[((dfAll.Cat=='Mortgage')|(dfAll.Cat=='MortgageRefund'))&(dfAll.Account!='60-83-71 00558156')].groupby(['Account','Cat']).Amount.sum()
dfMtg=dfMtg.reset_index().pivot('Account','Cat')
dfMtg.columns=dfMtg.columns.get_level_values(1)
if('MortgageRefund' not in dfMtg.columns):
    dfMtg['MortgageRefund']=0
dfMtg['Diff']=dfMtg.Mortgage + dfMtg.MortgageRefund
dfMtg
# Out:
# Cat                Mortgage  MortgageRefund     Diff
# Account
# 20-53-97 30728691  -20874.4               0 -20874.4

# %%
dfMtg['Diff'].sum()
# Out:
# -20874.399999999998

# %% [markdown]
# #### Rent check
# Rents going to wrong account

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='OurRent')]
# Out:
# Empty DataFrame
# Columns: [Account, Amount, Subcategory, Memo, Property, Description, Cat, Subcat]
# Index: []

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='OurRent')].groupby(['Cat']).sum()
# Out:
# Empty DataFrame
# Columns: [Amount, Description]
# Index: []

# %% [markdown]
# #### Property expense check
# Property expenses and service charges taken from 3072 or 6045

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='PropertyExpense')]
# Out:
#                       Account  Amount     Subcategory  \
# 2025-10-10  20-74-09 60458872   -15.0  Standing Order
# 2025-10-10  20-74-09 60458872    15.0          Credit
#
#                                                   Memo Property  Description  \
# 2025-10-10        SSE SOUTHERN ELECT    6882766014 STO   169FAW          NaN
# 2025-10-10  SSE SOUTHERN E        6882766014 REV0001Pa   169FAW          NaN
#
#                         Cat Subcat
# 2025-10-10  PropertyExpense    NaN
# 2025-10-10  PropertyExpense    NaN

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='PropertyExpense')].groupby(['Cat']).sum()
# Out:
#                  Amount  Description
# Cat
# PropertyExpense     0.0          0.0

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='ServiceCharge')]
# Out:
# Empty DataFrame
# Columns: [Account, Amount, Subcategory, Memo, Property, Description, Cat, Subcat]
# Index: []

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='ServiceCharge')].groupby(['Cat']).sum()
# Out:
# Empty DataFrame
# Columns: [Amount, Description]
# Index: []

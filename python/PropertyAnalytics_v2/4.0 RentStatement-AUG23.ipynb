# %%
from mt_rent_statement import *

# %% [markdown]
# ### Load data

# %%
start='2023-08-01'
end='2023-08-31'
dfT=load_tenancies('all_tenancies.xls')
dfAll=load_data(start,end)
dfAll.head(3)
# Out:
# WARNING *** file size (106483) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Reading file: E:\dtuklaptop\e\Users\Mat\python\data\property\checked\AUG2023_codedAndCategorised.xlsx
# E:\dtuklaptop\e\Users\Mat\python\14. property\PropertyAnalytics_v2\mt_rent_statement.py:163: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   dfAll=pd.concat([dfAll,dfTemp])
#                       Account  Amount     Subcategory  \
# 2023-08-01  20-74-09 60458872  500.00  Counter Credit
# 2023-08-01  20-53-97 30728691 -575.86    Direct Debit
# 2023-08-01  20-53-97 30728691 -576.84    Direct Debit
#
#                                                 Memo  Property Description  \
# 2023-08-01        M Tucker BGC          M Tucker BGC       NaN         NaN
# 2023-08-01  PLATFORM FUNDING      01050229961090 DDR  F2246ALH         NaN
# 2023-08-01  PLATFORM FUNDING      01050229961082 DDR  F2046ALH         NaN
#
#                     Cat Subcat
# 2023-08-01  OtherIncome    NaN
# 2023-08-01     Mortgage    NaN
# 2023-08-01     Mortgage    NaN

# %% [markdown]
# ### Rent Statement

# %%
paidinadvancelist = ['Peter Gradon (28/02/2018)'] 
inarrearslist = ['Mark Williams (25/09/2019)']
dfRs=get_rent_statement(dfAll, dfT, start, end, inarrearslist, paidinadvancelist)
dfRs=dfRs.round(0)
#dfRs.sort_values(by=['Net'], ascending=False).style.apply(custom_style, axis=1)
#dfRs.sort_values(by=['Bills'], ascending=True).style.apply(custom_style, axis=1)
dfRs.style.apply(custom_style, axis=1)
# Out:
# <style  type="text/css" >
#     #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow0_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow0_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow0_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow0_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow0_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow0_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow0_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow1_col0 {
#             background-color:  lightgreen;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow1_col1 {
#             background-color:  lightgreen;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow1_col2 {
#             background-color:  lightgreen;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow1_col3 {
#             background-color:  lightgreen;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow1_col4 {
#             background-color:  lightgreen;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow1_col5 {
#             background-color:  lightgreen;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow1_col6 {
#             background-color:  lightgreen;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow2_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow2_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow2_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow2_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow2_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow2_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow2_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow3_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow3_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow3_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow3_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow3_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow3_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow3_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow4_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow4_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow4_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow4_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow4_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow4_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow4_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow5_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow5_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow5_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow5_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow5_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow5_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow5_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow6_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow6_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow6_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow6_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e0abe348_9ea8_11ee_aeaa_fcaa147063aarow6_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;

# %% [markdown]
# This month:
# - this was the month the 0.5% increase from 4.5% to 5% in June 23 took effect raising mortgage costs from 22500 to 24000

# %% [markdown]
# Notes:
# - F1 321 Chowdhury moved in day after Soumya Xaviour moved out, there were no Fox & Sons fees for this tenant
# - F17 46 Sophie Bedford moved out end of July, Camilla Bailey & Michael Gregson move in 31/08/23
#     - in September they paid 6 months in advance to 28/02/23
# - 23B Shyni Bijumon & Bijumon Varghese moved in 03/09/23, there were no Fox & Sons fees for this tenant
# - 23C Ancy Mathews & Mathews Jose moved in 08/10/23, there were no Fox & Sons fees for this tenant
# - F7 8 Ben Kendall & Gabriella Nouvet-Aruaz moved in 08/09/23
# - F22 46 Charlotte McLellan-Campbell and Jose Gongora Oliva moved in on 10/09/23
#     - in October they paid 6 months in advance to 19/04/23
# - F3 321 Shubi Agarwal is moving out 27/12/23 - she asked to move out a before end of tenancy which was agreed to when we found new tenants (some found for 28/12/23)
# - F11 1214 Betts died on 5th November, he paid to 25/11/23
# - F14 1214 McIlwraith moved out 11/11/23
# - F16 1618 Gradon was given notice because he had a guy living with him who was pissing on doorstep, he moved out 18/11/23. He had paid in advance, there was £2k to pay him back and some from Beals
#
#
# TODO:
# - Mark Williams didn't pay Oct 22
# - Ivana to check rent increases for Pedace, England, Milligan, Yates, Passmore
# - Check Brett, Milligan & Passmore arrears
# - F1 1618 Fyles missing payment in AUG23
# - F6 8 Bristow arrears NOV23
# - Brett rent
# - increase shop

# %% [markdown]
# ### Income/Expenditure per Property

# %%
plot_income_expenditure_per_property(dfRs[:-1])

# %% [markdown]
# ### Net Income Per Property

# %%
plot_net_income(dfRs[:-1])

# %% [markdown]
# ### Accounts Check
# Check Drawings against expenses

# %%
dfAll[(dfAll.Cat=='RegularPayment')|(dfAll.Cat=='PersonalExpense')|(dfAll.Cat=='Hilltop')|(dfAll.Cat=='HMRCDD')|(dfAll.Cat=='Drawings')|(dfAll.Cat=='SchoolFee')].groupby(['Cat']).sum()
# Out:
#                   Amount
# Cat
# HMRCDD           -300.00
# Hilltop          -300.00
# PersonalExpense -2761.46
# RegularPayment  -1152.66

# %%
dfAll.groupby(['Account','Cat']).sum().style.apply(custom_style_accounts_cat, axis=1)
# Out:
# <style  type="text/css" >
#     #T_e2042008_9ea8_11ee_a7df_fcaa147063aarow0_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e2042008_9ea8_11ee_a7df_fcaa147063aarow1_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e2042008_9ea8_11ee_a7df_fcaa147063aarow2_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e2042008_9ea8_11ee_a7df_fcaa147063aarow3_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e2042008_9ea8_11ee_a7df_fcaa147063aarow4_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e2042008_9ea8_11ee_a7df_fcaa147063aarow5_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e2042008_9ea8_11ee_a7df_fcaa147063aarow6_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e2042008_9ea8_11ee_a7df_fcaa147063aarow7_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e2042008_9ea8_11ee_a7df_fcaa147063aarow8_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e2042008_9ea8_11ee_a7df_fcaa147063aarow9_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e2042008_9ea8_11ee_a7df_fcaa147063aarow10_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e2042008_9ea8_11ee_a7df_fcaa147063aarow11_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e2042008_9ea8_11ee_a7df_fcaa147063aarow12_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e2042008_9ea8_11ee_a7df_fcaa147063aarow13_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e2042008_9ea8_11ee_a7df_fcaa147063aarow14_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e2042008_9ea8_11ee_a7df_fcaa147063aarow15_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e2042008_9ea8_11ee_a7df_fcaa147063aarow16_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e2042008_9ea8_11ee_a7df_fcaa147063aarow17_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e2042008_9ea8_11ee_a7df_fcaa147063aarow18_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e2042008_9ea8_11ee_a7df_fcaa147063aarow19_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e2042008_9ea8_11ee_a7df_fcaa147063aarow20_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e2042008_9ea8_11ee_a7df_fcaa147063aarow21_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e2042008_9ea8_11ee_a7df_fcaa147063aarow22_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e2042008_9ea8_11ee_a7df_fcaa147063aarow23_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e2042008_9ea8_11ee_a7df_fcaa147063aarow24_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e2042008_9ea8_11ee_a7df_fcaa147063aarow25_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }</style><table id="T_e2042008_9ea8_11ee_a7df_fcaa147063aa" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Amount</th>    </tr>    <tr>        <th class="index_name level0" >Account</th>        <th class="index_name level1" >Cat</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e2042008_9ea8_11ee_a7df_fcaa147063aalevel0_row0" class="row_heading level0 row0" rowspan=7>20-53-97 30728691</th>
#                         <th id="T_e2042008_9ea8_11ee_a7df_fcaa147063aalevel1_row0" class="row_heading level1 row0" >Deposit</th>
#                         <td id="T_e2042008_9ea8_11ee_a7df_fcaa147063aarow0_col0" class="data row0 col0" >508.77</td>
#             </tr>
#             <tr>
#                                 <th id="T_e2042008_9ea8_11ee_a7df_fcaa147063aalevel1_row1" class="row_heading level1 row1" >HMRCDD</th>
#                         <td id="T_e2042008_9ea8_11ee_a7df_fcaa147063aarow1_col0" class="data row1 col0" >-300</td>
#             </tr>
#             <tr>
#                                 <th id="T_e2042008_9ea8_11ee_a7df_fcaa147063aalevel1_row2" class="row_heading level1 row2" >Mortgage</th>
#                         <td id="T_e2042008_9ea8_11ee_a7df_fcaa147063aarow2_col0" class="data row2 col0" >-24088</td>
#             </tr>
#             <tr>
#                                 <th id="T_e2042008_9ea8_11ee_a7df_fcaa147063aalevel1_row3" class="row_heading level1 row3" >OtherExpense</th>
#                         <td id="T_e2042008_9ea8_11ee_a7df_fcaa147063aarow3_col0" class="data row3 col0" >-4.41</td>
#             </tr>
#             <tr>
#                                 <th id="T_e2042008_9ea8_11ee_a7df_fcaa147063aalevel1_row4" class="row_heading level1 row4" >OtherIncome</th>
#                         <td id="T_e2042008_9ea8_11ee_a7df_fcaa147063aarow4_col0" class="data row4 col0" >24513.9</td>
#             </tr>
#             <tr>
#                                 <th id="T_e2042008_9ea8_11ee_a7df_fcaa147063aalevel1_row5" class="row_heading level1 row5" >PropertyExpense</th>
#                         <td id="T_e2042008_9ea8_11ee_a7df_fcaa147063aarow5_col0" class="data row5 col0" >-574.01</td>
#             </tr>
#             <tr>
#                                 <th id="T_e2042008_9ea8_11ee_a7df_fcaa147063aalevel1_row6" class="row_heading level1 row6" >RegularPayment</th>
#                         <td id="T_e2042008_9ea8_11ee_a7df_fcaa147063aarow6_col0" class="data row6 col0" >-630.25</td>
#             </tr>
#             <tr>
#                         <th id="T_e2042008_9ea8_11ee_a7df_fcaa147063aalevel0_row7" class="row_heading level0 row7" rowspan=4>20-74-09 40406538</th>
#                         <th id="T_e2042008_9ea8_11ee_a7df_fcaa147063aalevel1_row7" class="row_heading level1 row7" >OtherExpense</th>
#                         <td id="T_e2042008_9ea8_11ee_a7df_fcaa147063aarow7_col0" class="data row7 col0" >-3.91</td>
#             </tr>
#             <tr>
#                                 <th id="T_e2042008_9ea8_11ee_a7df_fcaa147063aalevel1_row8" class="row_heading level1 row8" >OtherIncome</th>
#                         <td id="T_e2042008_9ea8_11ee_a7df_fcaa147063aarow8_col0" class="data row8 col0" >2700</td>
#             </tr>
#             <tr>
#                                 <th id="T_e2042008_9ea8_11ee_a7df_fcaa147063aalevel1_row9" class="row_heading level1 row9" >PersonalExpense</th>
#                         <td id="T_e2042008_9ea8_11ee_a7df_fcaa147063aarow9_col0" class="data row9 col0" >-2

# %% [markdown]
# #### Mortgage check
# Check mortgages refunded from business account

# %%
dfMtg=dfAll[((dfAll.Cat=='Mortgage')|(dfAll.Cat=='MortgageRefund'))&(dfAll.Account!='60-83-71 00558156')].groupby(['Account','Cat']).Amount.sum()
dfMtg=dfMtg.reset_index().pivot('Account','Cat')
dfMtg.columns=dfMtg.columns.get_level_values(1)
if('MortgageRefund' not in dfMtg.columns):
    dfMtg['MortgageRefund']=0
dfMtg['Diff']=dfMtg.Mortgage + dfMtg.MortgageRefund
dfMtg
# Out:
# Cat                Mortgage  MortgageRefund      Diff
# Account
# 20-53-97 30728691 -24088.03               0 -24088.03

# %%
dfMtg['Diff'].sum()
# Out:
# -24088.030000000006

# %% [markdown]
# #### Rent check
# Rents going to wrong account

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='OurRent')]
# Out:
# Empty DataFrame
# Columns: [Account, Amount, Subcategory, Memo, Property, Description, Cat, Subcat]
# Index: []

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='OurRent')].groupby(['Cat']).sum()
# Out:
# Empty DataFrame
# Columns: [Amount]
# Index: []

# %% [markdown]
# #### Property expense check
# Property expenses and service charges taken from 3072 or 6045

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='PropertyExpense')]
# Out:
#                       Account  Amount     Subcategory  \
# 2023-08-18  20-74-09 60458872  -15.00  Standing Order
# 2023-02-28  20-53-97 30728691 -574.01             NaN
#
#                                             Memo  Property  \
# 2023-08-18  SSE SOUTHERN ELECT    6882766014 STO    169FAW
# 2023-02-28             Fox & Sons (£475.99 paid)  F2146ALH
#
#                                                   Description  \
# 2023-08-18                                                NaN
# 2023-02-28  No sure about this charge from Fox & Sons coul...
#
#                         Cat Subcat
# 2023-08-18  PropertyExpense    NaN
# 2023-02-28  PropertyExpense    NaN

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='PropertyExpense')].groupby(['Cat']).sum()
# Out:
#                  Amount
# Cat
# PropertyExpense -589.01

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='ServiceCharge')]
# Out:
# Empty DataFrame
# Columns: [Account, Amount, Subcategory, Memo, Property, Description, Cat, Subcat]
# Index: []

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='ServiceCharge')].groupby(['Cat']).sum()
# Out:
# Empty DataFrame
# Columns: [Amount]
# Index: []

# %%
from mt_rent_statement import *

# %% [markdown]
# ### Load data

# %%
start='2022-10-01'
end='2022-10-31'
dfT=load_tenancies('all_tenancies.xls')
dfAll=load_data(start,end)
dfAll.head(3)
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Reading file: E:\dtuklaptop\e\Users\Mat\python\data\property\checked\OCT2022_codedAndCategorised.xlsx
# E:\dtuklaptop\e\Users\Mat\python\14. property\PropertyAnalytics_v2\mt_rent_statement.py:163: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   dfAll=pd.concat([dfAll,dfTemp])
#                       Account   Amount        Subcategory  \
# 2022-10-01  60-83-71 00558156   600.00            REVENUE
# 2022-10-01  60-83-71 00558156    -6.85              ADMIN
# 2022-10-01  60-83-71 00558156 -2691.42  INTEREST_PAYMENTS
#
#                                                          Memo   Property  \
# 2022-10-01                              NATSO P OCTOBER RENT    F4163FRA
# 2022-10-01  Post Office POST OFFICE COUNTER keys to fox an...  F31618ALH
# 2022-10-01                         Ivana Valentino Mortgages         NaN
#
#            Description              Cat Subcat
# 2022-10-01         NaN          OurRent    NaN
# 2022-10-01         NaN  PropertyExpense    NaN
# 2022-10-01         NaN   MortgageRefund    NaN

# %% [markdown]
# ### Rent Statement

# %%
paidinadvancelist = ['Jason Moore (23/05/2022)','Peter Gradon (28/02/2018)'] # November
dfRs=get_rent_statement(dfAll, dfT, start, end, [], paidinadvancelist)
dfRs=dfRs.round(0)
#dfRs.sort_values(by=['Net'], ascending=False).style.apply(custom_style, axis=1)
#dfRs.sort_values(by=['Bills'], ascending=True).style.apply(custom_style, axis=1)
dfRs.style.apply(custom_style, axis=1)
# Out:
# <style  type="text/css" >
#     #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow0_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow0_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow0_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow0_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow0_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow0_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow0_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow1_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow1_col1 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow1_col2 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow1_col3 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow1_col4 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow1_col5 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow1_col6 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow2_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow2_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow2_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow2_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow2_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow2_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow2_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow3_col0 {
#             background-color:  lightgreen;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow3_col1 {
#             background-color:  lightgreen;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow3_col2 {
#             background-color:  lightgreen;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow3_col3 {
#             background-color:  lightgreen;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow3_col4 {
#             background-color:  lightgreen;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow3_col5 {
#             background-color:  lightgreen;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow3_col6 {
#             background-color:  lightgreen;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow4_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow4_col1 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow4_col2 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow4_col3 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow4_col4 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow4_col5 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow4_col6 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow5_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow5_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow5_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow5_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow5_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow5_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow5_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow6_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow6_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow6_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow6_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_28fd8786_8aa5_11ed_b3e6_fcaa147063aarow6_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:

# %% [markdown]
# Notes:
# - Susheel move out
# - 5 empty -> F1, 321, F3 321, F4 321, F8 46, F20 46
# - Mark Williams didn't pay
# - Moore to start paying again in Dec
# - Graddon paid 6 months advance in Sept to March - Gradon was served S13 rent increase

# %% [markdown]
# ### Income/Expenditure per Property

# %%
plot_income_expenditure_per_property(dfRs[:-1])

# %% [markdown]
# ### Net Income Per Property

# %%
plot_net_income(dfRs[:-1])

# %% [markdown]
# ### Accounts Check
# Check Drawings against expenses

# %%
dfAll[(dfAll.Cat=='RegularPayment')|(dfAll.Cat=='PersonalExpense')|(dfAll.Cat=='Hilltop')|(dfAll.Cat=='HMRCDD')|(dfAll.Cat=='Drawings')|(dfAll.Cat=='SchoolFee')].groupby(['Cat']).sum()
# Out:
#                   Amount
# Cat
# Drawings        -4145.23
# HMRCDD           -600.00
# Hilltop          -300.00
# PersonalExpense -4399.76
# RegularPayment  -1126.38
# SchoolFee       -5688.99

# %%
dfAll.groupby(['Account','Cat']).sum().style.apply(custom_style_accounts_cat, axis=1)
# Out:
# <style  type="text/css" >
#     #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow0_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow1_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow2_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow3_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow4_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow5_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow6_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow7_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow8_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow9_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow10_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow11_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow12_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow13_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow14_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow15_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow16_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow17_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow18_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow19_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow20_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow21_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow22_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow23_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow24_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow25_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow26_col0 {
#             background-color:  pink;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow27_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow28_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow29_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow30_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow31_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }</style><table id="T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aa" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Amount</th>    </tr>    <tr>        <th class="index_name level0" >Account</th>        <th class="index_name level1" >Cat</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aalevel0_row0" class="row_heading level0 row0" rowspan=10>20-53-97 30728691</th>
#                         <th id="T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aalevel1_row0" class="row_heading level1 row0" >Deposit</th>
#                         <td id="T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow0_col0" class="data row0 col0" >0</td>
#             </tr>
#             <tr>
#                                 <th id="T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aalevel1_row1" class="row_heading level1 row1" >Funds3072</th>
#                         <td id="T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow1_col0" class="data row1 col0" >1200</td>
#             </tr>
#             <tr>
#                                 <th id="T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aalevel1_row2" class="row_heading level1 row2" >HMRCDD</th>
#                         <td id="T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow2_col0" class="data row2 col0" >-300</td>
#             </tr>
#             <tr>
#                                 <th id="T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aalevel1_row3" class="row_heading level1 row3" >Mortgage</th>
#                         <td id="T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow3_col0" class="data row3 col0" >-5490.42</td>
#             </tr>
#             <tr>
#                                 <th id="T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aalevel1_row4" class="row_heading level1 row4" >MortgageRefund</th>
#                         <td id="T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow4_col0" class="data row4 col0" >4985.81</td>
#             </tr>
#             <tr>
#                                 <th id="T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aalevel1_row5" class="row_heading level1 row5" >OtherIncome</th>
#                         <td id="T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow5_col0" class="data row5 col0" >1800</td>
#             </tr>
#             <tr>
#                                 <th id="T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aalevel1_row6" class="row_heading level1 row6" >OurRent</th>
#                         <td id="T_2a798e7a_8aa5_11ed_8cf3_fcaa147063aarow6_col0" class="data row6 col0" >-220</td>
#             <

# %% [markdown]
# #### Mortgage check
# Check mortgages refunded from business account

# %%
dfMtg=dfAll[((dfAll.Cat=='Mortgage')|(dfAll.Cat=='MortgageRefund'))&(dfAll.Account!='60-83-71 00558156')].groupby(['Account','Cat']).Amount.sum()
dfMtg=dfMtg.reset_index().pivot('Account','Cat')
dfMtg.columns=dfMtg.columns.get_level_values(1)
if('MortgageRefund' not in dfMtg.columns):
    dfMtg['MortgageRefund']=0
dfMtg['Diff']=dfMtg.Mortgage + dfMtg.MortgageRefund
dfMtg
# Out:
# Cat                Mortgage  MortgageRefund     Diff
# Account
# 20-53-97 30728691  -5490.42         4985.81  -504.61
# 20-74-09 60458872  -7800.67         6728.66 -1072.01

# %%
dfMtg['Diff'].sum()
# Out:
# -1576.6200000000008

# %% [markdown]
# #### Rent check
# Rents going to wrong account

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='OurRent')]
# Out:
#                       Account  Amount     Subcategory  \
# 2022-10-03  20-53-97 30728691  -820.0    Bill Payment
# 2022-10-07  20-53-97 30728691   260.0  Counter Credit
# 2022-10-14  20-53-97 30728691  -260.0    Bill Payment
# 2022-10-25  20-53-97 30728691   600.0  Standing Order
#
#                                                    Memo    Property  \
# 2022-10-03  RSA CAPITAL LIMITE    MWILLIAMS 196BRENT BB     196BKIN
# 2022-10-07   FLAT3 321LONDON RD    SEQUENCE UK LIMI BGC    F3321LON
# 2022-10-14      RSA CAPITAL LIMITE    3321 REM RENT BBP    F3321LON
# 2022-10-25  MR MICHAEL BETTS      FT11 12-14ALHAMBRA ST  F111214ALH
#
#            Description      Cat Subcat
# 2022-10-03         NaN  OurRent    NaN
# 2022-10-07         NaN  OurRent    NaN
# 2022-10-14         NaN  OurRent    NaN
# 2022-10-25         NaN  OurRent    NaN

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='OurRent')].groupby(['Cat']).sum()
# Out:
#          Amount
# Cat
# OurRent  -220.0

# %% [markdown]
# #### Property expense check
# Property expenses and service charges taken from 3072 or 6045

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='PropertyExpense')]
# Out:
#                       Account  Amount     Subcategory  \
# 2022-10-14  20-74-09 60458872   -15.0  Standing Order
#
#                                             Memo Property Description  \
# 2022-10-14  SSE SOUTHERN ELECT    6882766014 STO   169FAW         NaN
#
#                         Cat Subcat
# 2022-10-14  PropertyExpense    NaN

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='PropertyExpense')].groupby(['Cat']).sum()
# Out:
#                  Amount
# Cat
# PropertyExpense   -15.0

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='ServiceCharge')]
# Out:
#                       Account  Amount     Subcategory  \
# 2022-10-03  20-53-97 30728691  -232.5  Standing Order
# 2022-10-03  20-53-97 30728691  -157.5  Standing Order
# 2022-10-03  20-53-97 30728691  -160.0  Standing Order
# 2022-10-03  20-53-97 30728691   -50.0  Standing Order
# 2022-10-03  20-74-09 60458872  -232.5  Standing Order
# 2022-10-03  20-74-09 60458872  -160.0  Standing Order
# 2022-10-03  20-74-09 60458872   -50.0  Standing Order
# 2022-10-03  20-74-09 60458872  -157.5  Standing Order
#
#                                                  Memo Property Description  \
# 2022-10-03  ALHAMBRA ROAD MANA    209254 83672832 STO      NaN         NaN
# 2022-10-03  ALHAMBRA ROAD MANA    209254 23534332 STO      NaN         NaN
# 2022-10-03  ALHAMBRA ROAD MANA    209254 13686035 STO      NaN         NaN
# 2022-10-03  23 HAMPSHIRE TERRA    209254 13676978 STO      NaN         NaN
# 2022-10-03  4-6 ALHAMBRA RD CS    209254 83672832 STO      NaN         NaN
# 2022-10-03  16-18 ALHAMBRA RD     209254 13686035 STO      NaN         NaN
# 2022-10-03  23 HAMPSHIRE TERRA    209254 13676978 STO      NaN         NaN
# 2022-10-03  12-14 ALHAMBRA RD     209254 23534332 STO      NaN         NaN
#
#                       Cat Subcat
# 2022-10-03  ServiceCharge    NaN
# 2022-10-03  ServiceCharge    NaN
# 2022-10-03  ServiceCharge    NaN
# 2022-10-03  ServiceCharge    NaN
# 2022-10-03  ServiceCharge    NaN
# 2022-10-03  ServiceCharge    NaN
# 2022-10-03  ServiceCharge    NaN
# 2022-10-03  ServiceCharge    NaN

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='ServiceCharge')].groupby(['Cat']).sum()
# Out:
#                Amount
# Cat
# ServiceCharge -1200.0

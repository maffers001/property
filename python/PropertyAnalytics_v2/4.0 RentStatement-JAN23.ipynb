# %%
from mt_rent_statement import *

# %% [markdown]
# ### Load data

# %%
start='2023-01-01'
end='2023-01-31'
dfT=load_tenancies('all_tenancies.xls')
dfAll=load_data(start,end)
dfAll.head(3)
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Reading file: E:\dtuklaptop\e\Users\Mat\python\data\property\checked\JAN2023_codedAndCategorised.xlsx
# E:\dtuklaptop\e\Users\Mat\python\14. property\PropertyAnalytics_v2\mt_rent_statement.py:163: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   dfAll=pd.concat([dfAll,dfTemp])
#                       Account  Amount              Subcategory  \
# 2023-01-01  60-83-71 00558156   600.0                  REVENUE
# 2023-01-01  60-83-71 00558156   900.0                  REVENUE
# 2023-01-01  60-83-71 00558156  -315.0  REPAIRS_AND_MAINTENANCE
#
#                                      Memo  Property  Description  \
# 2023-01-01          NATSO P JANUARY RENT   F4163FRA          NaN
# 2023-01-01  C Prescott FLAT 3 321 LDN RD   F3321LON          NaN
# 2023-01-01    ALHHAMBRA ROAD M Tucker SC        NaN          NaN
#
#                       Cat Subcat
# 2023-01-01        OurRent    NaN
# 2023-01-01        OurRent    NaN
# 2023-01-01  ServiceCharge    NaN

# %% [markdown]
# ### Rent Statement

# %%
paidinadvancelist = ['Peter Gradon (28/02/2018)'] 
inarrearslist = ['Mark Williams (25/09/2019)']
dfRs=get_rent_statement(dfAll, dfT, start, end, inarrearslist, paidinadvancelist)
dfRs=dfRs.round(0)
#dfRs.sort_values(by=['Net'], ascending=False).style.apply(custom_style, axis=1)
#dfRs.sort_values(by=['Bills'], ascending=True).style.apply(custom_style, axis=1)
dfRs.style.apply(custom_style, axis=1)
# Out:
# <style  type="text/css" >
#     #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow0_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow0_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow0_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow0_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow0_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow0_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow0_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow1_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow1_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow1_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow1_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow1_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow1_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow1_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow2_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow2_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow2_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow2_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow2_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow2_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow2_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow3_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow3_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow3_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow3_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow3_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow3_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow3_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow4_col0 {
#             background-color:  lightgreen;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow4_col1 {
#             background-color:  lightgreen;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow4_col2 {
#             background-color:  lightgreen;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow4_col3 {
#             background-color:  lightgreen;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow4_col4 {
#             background-color:  lightgreen;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow4_col5 {
#             background-color:  lightgreen;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow4_col6 {
#             background-color:  lightgreen;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow5_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow5_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow5_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow5_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow5_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow5_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow5_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow6_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow6_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow6_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow6_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_df54b7f6_ad67_11ed_9385_fcaa147063aarow6_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;

# %% [markdown]
# This month:
#
# - rate 3.5%

# %% [markdown]
# Notes:
# - Valverde evicted 26/01/23, Radzevics 13/12/22
# - Hinks bailiff date is 10/03/23 and Austin court papers sent early Feb
# - Mark Williams didn't pay Oct
# - Graddon paid 6 months advance in Sept to March - Gradon was served S13 rent increase and paid the difference in Jan 23
# - Ivana to check rent increases for:
#     - Parkinson
#     - Pedace
#     - Passmore
#     - Henson
# - Beals messed up S21 in Feb, need to give again in March
# - Plan to give S13 to Henson on 01/03/22
# - ** Need to refund Fratton roof payment in Jan

# %% [markdown]
# ### Income/Expenditure per Property

# %%
plot_income_expenditure_per_property(dfRs[:-1])

# %% [markdown]
# ### Net Income Per Property

# %%
plot_net_income(dfRs[:-1])

# %% [markdown]
# ### Accounts Check
# Check Drawings against expenses

# %%
dfAll[(dfAll.Cat=='RegularPayment')|(dfAll.Cat=='PersonalExpense')|(dfAll.Cat=='Hilltop')|(dfAll.Cat=='HMRCDD')|(dfAll.Cat=='Drawings')|(dfAll.Cat=='SchoolFee')].groupby(['Cat']).sum()
# Out:
#                   Amount  Description
# Cat
# Drawings            0.00          0.0
# HMRCDD           -600.00          0.0
# Hilltop          -300.00          0.0
# PersonalExpense -3577.98          0.0
# RegularPayment   6092.13          0.0
# SchoolFee       -5684.82          0.0

# %%
dfAll.groupby(['Account','Cat']).sum().style.apply(custom_style_accounts_cat, axis=1)
# Out:
# <style  type="text/css" >
#     #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow0_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow0_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow1_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow1_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow2_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow2_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow3_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow3_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow4_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow4_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow5_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow5_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow6_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow6_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow7_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow7_col1 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow8_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow8_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow9_col0 {
#             background-color:  pink;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow9_col1 {
#             background-color:  pink;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow10_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow10_col1 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow11_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow11_col1 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow12_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow12_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow13_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow13_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow14_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow14_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow15_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow15_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow16_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow16_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow17_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow17_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow18_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow18_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow19_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow19_col1 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow20_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow20_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow21_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow21_col1 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow22_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow22_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_e10ca6f6_ad67_11ed_b398_fcaa147063aarow23_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;

# %% [markdown]
# #### Mortgage check
# Check mortgages refunded from business account

# %%
dfMtg=dfAll[((dfAll.Cat=='Mortgage')|(dfAll.Cat=='MortgageRefund'))&(dfAll.Account!='60-83-71 00558156')].groupby(['Account','Cat']).Amount.sum()
dfMtg=dfMtg.reset_index().pivot('Account','Cat')
dfMtg.columns=dfMtg.columns.get_level_values(1)
if('MortgageRefund' not in dfMtg.columns):
    dfMtg['MortgageRefund']=0
dfMtg['Diff']=dfMtg.Mortgage + dfMtg.MortgageRefund
dfMtg
# Out:
# Cat                Mortgage  MortgageRefund     Diff
# Account
# 20-53-97 30728691 -10707.14         8294.39 -2412.75
# 20-74-09 60458872  -7711.62         6728.66  -982.96

# %%
dfMtg['Diff'].sum()
# Out:
# -3395.7099999999946

# %% [markdown]
# #### Rent check
# Rents going to wrong account

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='OurRent')]
# Out:
#                       Account  Amount     Subcategory  \
# 2023-01-05  20-53-97 30728691  -675.0    Bill Payment
# 2023-01-31  20-53-97 30728691  -820.0    Bill Payment
# 2023-01-31  20-53-97 30728691   820.0  Counter Credit
#
#                                                    Memo    Property  \
# 2023-01-05  RSA CAPITAL LIMITE    M BETTSRENT 111214 BB  F111618ALH
# 2023-01-31  RSA CAPITAL LIMITE    MWILLIAMS 196BRENT BB     196BKIN
# 2023-01-31               M Williams            RENT BGC     196BKIN
#
#             Description      Cat Subcat
# 2023-01-05          NaN  OurRent    NaN
# 2023-01-31          NaN  OurRent    NaN
# 2023-01-31          NaN  OurRent    NaN

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='OurRent')].groupby(['Cat']).sum()
# Out:
#          Amount  Description
# Cat
# OurRent  -675.0          0.0

# %% [markdown]
# #### Property expense check
# Property expenses and service charges taken from 3072 or 6045

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='PropertyExpense')]
# Out:
#                       Account  Amount     Subcategory  \
# 2023-01-06  20-74-09 60458872   -15.0  Standing Order
#
#                                             Memo Property  Description  \
# 2023-01-06  SSE SOUTHERN ELECT    6882766014 STO   169FAW          NaN
#
#                         Cat Subcat
# 2023-01-06  PropertyExpense    NaN

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='PropertyExpense')].groupby(['Cat']).sum()
# Out:
#                  Amount  Description
# Cat
# PropertyExpense   -15.0          0.0

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='ServiceCharge')]
# Out:
# Empty DataFrame
# Columns: [Account, Amount, Subcategory, Memo, Property, Description, Cat, Subcat]
# Index: []

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='ServiceCharge')].groupby(['Cat']).sum()
# Out:
# Empty DataFrame
# Columns: [Amount, Description]
# Index: []

# %%
from mt_rent_statement import *

# %% [markdown]
# ### Load data

# %%
start='2025-02-01'
end='2025-02-28'
dfT=load_tenancies('all_tenancies.xls')
dfAll=load_data(start,end)
dfAll.head(3)
# Out:
# WARNING *** file size (106483) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Reading file: J://My Drive//NAS//My Documents//Business//Property//Statements//working//python//data//property//checked//FEB2025_codedAndCategorised.xlsx
# J:\My Drive\NAS\My Documents\Business\Property\Statements\working\python\14. property\PropertyAnalytics_v2\mt_rent_statement.py:165: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   dfAll=pd.concat([dfAll,dfTemp])
#                       Account  Amount              Subcategory  \
# 2025-02-01  60-83-71 00558156  -465.0  REPAIRS_AND_MAINTENANCE
# 2025-02-01  60-83-71 00558156  -320.0  REPAIRS_AND_MAINTENANCE
# 2025-02-01  60-83-71 00558156   800.0                  REVENUE
#
#                                     Memo  Property  Description  \
# 2025-02-01    Alhambra Road M Tucker SC        NaN          NaN
# 2025-02-01    Alhambra Road M Tucker SC        NaN          NaN
# 2025-02-01  COTTER J FLAT17 ALHAMBRA RD   F1746ALH          NaN
#
#                       Cat Subcat
# 2025-02-01  ServiceCharge    NaN
# 2025-02-01  ServiceCharge    NaN
# 2025-02-01        OurRent    NaN

# %% [markdown]
# ### Rent Statement

# %%
paidinadvancelist = ['Peter Gradon (28/02/2018)','Camilla Bailey & Michael Gregson (31/08/2023)','Charlotte McLellan-Campbell & Jose Gongora Oliva (10/09/2023)']
inarrearslist = ['Mark Williams (25/09/2019)']
dfRs=get_rent_statement(dfAll, dfT, start, end, inarrearslist, paidinadvancelist)
dfRs=dfRs.round(0)
#dfRs.sort_values(by=['Net'], ascending=False).style.apply(custom_style, axis=1)
#dfRs.sort_values(by=['Bills'], ascending=True).style.apply(custom_style, axis=1)
dfRs.style.apply(custom_style, axis=1)
# Out:
# <style  type="text/css" >
#     #T_56cd8042_ac12_11f0_9434_fcaa147063aarow0_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow0_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow0_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow0_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow0_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow0_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow0_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow1_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow1_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow1_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow1_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow1_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow1_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow1_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow2_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow2_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow2_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow2_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow2_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow2_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow2_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow3_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow3_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow3_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow3_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow3_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow3_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow3_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow4_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow4_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow4_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow4_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow4_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow4_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow4_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow5_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow5_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow5_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow5_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow5_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow5_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow5_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow6_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow6_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow6_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow6_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_fcaa147063aarow6_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_56cd8042_ac12_11f0_9434_

# %% [raw]
# This month:
# - Susan Parkinson moved out
# - check Samuel Parkinson rent
# - Milligan died
# - F2 321 Cirprian is moving out on 25/01/24, he tried not to pay his last payment but his girlfriend paid
#
# Last month:
# - F3 321 Holman & Wolfe move in
# - F1 169 Susan Parkinson not paid
# - there were one off insurance expenses of £1355
# - no revenue received for 7 flats (1 non payer, 3 empties, 1 moving in, 2 paid in advance) and partial payment for 1
# - Parkinson, Brett underpayment
#
# Last month was low on revenue because 4 tenants paid in advance (Graddon, Fyles, Gregson, Oliva) and 3 moved out (Betts, McIllwraith, Gradon), 1 in arrears.
#
# This month similar revenue, 3 empty, 1 not paid, 2 paid in advance, 3 underpayments.
#
# TODO:
# - update move in/outs
# - Mark Williams didn't pay Oct 22
# - Ivana to check rent increases for Pedace, England, Yates, Passmore
# - Check Brett, Milligan & Passmore arrears
# - Brett rent
# - increase shop

# %% [markdown]
# Notes:
# - F1 321 Chowdhury moved in day after Soumya Xaviour moved out, there were no Fox & Sons fees for this tenant
# - F17 46 Sophie Bedford moved out end of July, Camilla Bailey & Michael Gregson move in 31/08/23
#     - in September they paid 6 months in advance to 28/02/23
# - 23B Shyni Bijumon & Bijumon Varghese moved in 03/09/23, there were no Fox & Sons fees for this tenant
# - 23C Ancy Mathews & Mathews Jose moved in 08/10/23, there were no Fox & Sons fees for this tenant
# - F7 8 Ben Kendall & Gabriella Nouvet-Aruaz moved in 08/09/23
# - F22 46 Charlotte McLellan-Campbell and Jose Gongora Oliva moved in on 10/09/23
#     - in October they paid 6 months in advance to 19/04/23
# - F3 321 Shubi Agarwal is moving out 27/12/23 - she asked to move out a before end of tenancy which was agreed to when we found new tenants (some found for 28/12/23)
# - F11 1214 Betts died on 5th November, he paid to 25/11/23
# - F14 1214 McIlwraith moved out 11/11/23
# - F16 1618 Gradon was given notice because he had a guy living with him who was pissing on doorstep, he moved out 18/11/23. He had paid in advance, there was £2k to pay him back and some from Beals
#
# Remarks:
# - each 0.25% increase in rates causes an increase in costs of £750 - ideally we need rates back at 4.5% to pay £22500 p/m
# - find out what happens when a business loans money to another and it is not repaid - ask Chatgpt
# - things should improve in March - by then hopefully empties rented, paid in advance start to pay again in March

# %% [markdown]
# ### Income/Expenditure per Property

# %%
plot_income_expenditure_per_property(dfRs[:-1])

# %% [markdown]
# ### Net Income Per Property

# %%
plot_net_income(dfRs[:-1])

# %% [markdown]
# ### Accounts Check
# Check Drawings against expenses

# %%
dfAll[(dfAll.Cat=='RegularPayment')|(dfAll.Cat=='PersonalExpense')|(dfAll.Cat=='Hilltop')|(dfAll.Cat=='HMRCDD')|(dfAll.Cat=='Drawings')|(dfAll.Cat=='SchoolFee')].groupby(['Cat']).sum()
# Out:
#                   Amount  Description
# Cat
# Hilltop          -300.00          0.0
# PersonalExpense -3127.01          0.0
# RegularPayment  -1188.81          0.0
# SchoolFee       -2806.66          0.0

# %%
dfAll.groupby(['Account','Cat']).sum().style.apply(custom_style_accounts_cat, axis=1)
# Out:
# <style  type="text/css" >
#     #T_5887de24_ac12_11f0_b852_fcaa147063aarow0_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow0_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow1_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow1_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow2_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow2_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow3_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow3_col1 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow4_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow4_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow5_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow5_col1 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow6_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow6_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow7_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow7_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow8_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow8_col1 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow9_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow9_col1 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow10_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow10_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow11_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow11_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow12_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow12_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow13_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow13_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow14_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow14_col1 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow15_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow15_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow16_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow16_col1 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow17_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow17_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow18_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow18_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow19_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow19_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow20_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow20_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow21_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow21_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow22_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow22_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_5887de24_ac12_11f0_b852_fcaa147063aarow23_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;

# %% [markdown]
# #### Mortgage check
# Check mortgages refunded from business account

# %%
dfMtg=dfAll[((dfAll.Cat=='Mortgage')|(dfAll.Cat=='MortgageRefund'))&(dfAll.Account!='60-83-71 00558156')].groupby(['Account','Cat']).Amount.sum()
dfMtg=dfMtg.reset_index().pivot('Account','Cat')
dfMtg.columns=dfMtg.columns.get_level_values(1)
if('MortgageRefund' not in dfMtg.columns):
    dfMtg['MortgageRefund']=0
dfMtg['Diff']=dfMtg.Mortgage + dfMtg.MortgageRefund
dfMtg
# Out:
# Cat                Mortgage  MortgageRefund      Diff
# Account
# 20-53-97 30728691 -23449.59               0 -23449.59

# %%
dfMtg['Diff'].sum()
# Out:
# -23449.59

# %% [markdown]
# #### Rent check
# Rents going to wrong account

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='OurRent')]
# Out:
# Empty DataFrame
# Columns: [Account, Amount, Subcategory, Memo, Property, Description, Cat, Subcat]
# Index: []

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='OurRent')].groupby(['Cat']).sum()
# Out:
# Empty DataFrame
# Columns: [Amount, Description]
# Index: []

# %% [markdown]
# #### Property expense check
# Property expenses and service charges taken from 3072 or 6045

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='PropertyExpense')]
# Out:
#                       Account  Amount     Subcategory  \
# 2025-02-03  20-53-97 30728691   400.0  Counter Credit
# 2025-02-28  20-74-09 60458872   -15.0  Standing Order
# 2025-02-28  20-74-09 60458872    15.0          Credit
#
#                                                   Memo  Property  Description  \
# 2025-02-03    THE DISPUTE SERVIC    TDS EW14380098 BGC  F1946ALH          NaN
# 2025-02-28        SSE SOUTHERN ELECT    6882766014 STO    169FAW          NaN
# 2025-02-28  SSE SOUTHERN E        6882766014 REV1114Pa    169FAW          NaN
#
#                         Cat Subcat
# 2025-02-03  PropertyExpense    NaN
# 2025-02-28  PropertyExpense    NaN
# 2025-02-28  PropertyExpense    NaN

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='PropertyExpense')].groupby(['Cat']).sum()
# Out:
#                  Amount  Description
# Cat
# PropertyExpense   400.0          0.0

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='ServiceCharge')]
# Out:
# Empty DataFrame
# Columns: [Account, Amount, Subcategory, Memo, Property, Description, Cat, Subcat]
# Index: []

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='ServiceCharge')].groupby(['Cat']).sum()
# Out:
# Empty DataFrame
# Columns: [Amount, Description]
# Index: []

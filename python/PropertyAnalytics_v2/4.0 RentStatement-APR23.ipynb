# %%
from mt_rent_statement import *

# %% [markdown]
# ### Load data

# %%
start='2023-04-01'
end='2023-04-30'
dfT=load_tenancies('all_tenancies.xls')
dfAll=load_data(start,end)
dfAll.head(3)
# Out:
# WARNING *** file size (103480) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# Reading file: E:\dtuklaptop\e\Users\Mat\python\data\property\checked\APR2023_codedAndCategorised.xlsx
# E:\dtuklaptop\e\Users\Mat\python\14. property\PropertyAnalytics_v2\mt_rent_statement.py:163: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   dfAll=pd.concat([dfAll,dfTemp])
#                       Account  Amount              Subcategory  \
# 2023-04-01  60-83-71 00558156  -465.0  REPAIRS_AND_MAINTENANCE
# 2023-04-01  60-83-71 00558156  -315.0  REPAIRS_AND_MAINTENANCE
# 2023-04-01  60-83-71 00558156   950.0                  REVENUE
#
#                                    Memo Property Description            Cat  \
# 2023-04-01   Alhambra Road M Tucker SC       NaN         NaN  ServiceCharge
# 2023-04-01  ALHHAMBRA ROAD M Tucker SC       NaN         NaN  ServiceCharge
# 2023-04-01         HICKS S 23BHAMPTERR    23BHAM         NaN        OurRent
#
#            Subcat
# 2023-04-01    NaN
# 2023-04-01    NaN
# 2023-04-01    NaN

# %% [markdown]
# ### Rent Statement

# %%
paidinadvancelist = ['Peter Gradon (28/02/2018)'] 
inarrearslist = ['Mark Williams (25/09/2019)']
dfRs=get_rent_statement(dfAll, dfT, start, end, inarrearslist, paidinadvancelist)
dfRs=dfRs.round(0)
#dfRs.sort_values(by=['Net'], ascending=False).style.apply(custom_style, axis=1)
#dfRs.sort_values(by=['Bills'], ascending=True).style.apply(custom_style, axis=1)
dfRs.style.apply(custom_style, axis=1)
# Out:
# <style  type="text/css" >
#     #T_208bf226_ff9c_11ed_adc6_4a225492749frow0_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow0_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow0_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow0_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow0_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow0_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow0_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow1_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow1_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow1_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow1_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow1_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow1_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow1_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow2_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow2_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow2_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow2_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow2_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow2_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow2_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow3_col0 {
#             background-color:  red;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow3_col1 {
#             background-color:  red;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow3_col2 {
#             background-color:  red;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow3_col3 {
#             background-color:  red;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow3_col4 {
#             background-color:  red;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow3_col5 {
#             background-color:  red;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow3_col6 {
#             background-color:  red;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow4_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow4_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow4_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow4_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow4_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow4_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow4_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow5_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow5_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow5_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow5_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow5_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow5_col5 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow5_col6 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow6_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow6_col1 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow6_col2 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow6_col3 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749frow6_col4 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_208bf226_ff9c_11ed_adc6_4a225492749fro

# %% [markdown]
# This month:
# - rate 4.0%

# %% [markdown]
# Notes:
# - Valverde evicted 26/01/23, Radzevics 13/12/22, Hinks 10/02/23, Austin 03/04/23
# - Mark Williams didn't pay Oct
# - Graddon paid 6 months advance in Sept to March - Gradon was served S13 rent increase and paid the difference in Jan 23
# - Ivana to check rent increases for:
#     - Parkinson
#     - Pedace
#     - Passmore
#     - Henson
# - F1 171 rent raised to £875 on 06/03/23
# - Plan to give S13 to Henson on 01/03/23
# - ** Need to refund Fratton roof payment in Jan

# %% [markdown]
# ### Income/Expenditure per Property

# %%
plot_income_expenditure_per_property(dfRs[:-1])

# %% [markdown]
# ### Net Income Per Property

# %%
plot_net_income(dfRs[:-1])

# %% [markdown]
# ### Accounts Check
# Check Drawings against expenses

# %%
dfAll[(dfAll.Cat=='RegularPayment')|(dfAll.Cat=='PersonalExpense')|(dfAll.Cat=='Hilltop')|(dfAll.Cat=='HMRCDD')|(dfAll.Cat=='Drawings')|(dfAll.Cat=='SchoolFee')].groupby(['Cat']).sum()
# Out:
#                   Amount
# Cat
# Drawings         -877.00
# HMRCDD           -300.00
# Hilltop          -300.00
# PersonalExpense -2376.64
# RegularPayment  -1145.73

# %%
dfAll.groupby(['Account','Cat']).sum().style.apply(custom_style_accounts_cat, axis=1)
# Out:
# <style  type="text/css" >
#     #T_22085ab8_ff9c_11ed_a732_4a225492749frow0_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_22085ab8_ff9c_11ed_a732_4a225492749frow1_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_22085ab8_ff9c_11ed_a732_4a225492749frow2_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_22085ab8_ff9c_11ed_a732_4a225492749frow3_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_22085ab8_ff9c_11ed_a732_4a225492749frow4_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_22085ab8_ff9c_11ed_a732_4a225492749frow5_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_22085ab8_ff9c_11ed_a732_4a225492749frow6_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_22085ab8_ff9c_11ed_a732_4a225492749frow7_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_22085ab8_ff9c_11ed_a732_4a225492749frow8_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_22085ab8_ff9c_11ed_a732_4a225492749frow9_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_22085ab8_ff9c_11ed_a732_4a225492749frow10_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_22085ab8_ff9c_11ed_a732_4a225492749frow11_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_22085ab8_ff9c_11ed_a732_4a225492749frow12_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_22085ab8_ff9c_11ed_a732_4a225492749frow13_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_22085ab8_ff9c_11ed_a732_4a225492749frow14_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_22085ab8_ff9c_11ed_a732_4a225492749frow15_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_22085ab8_ff9c_11ed_a732_4a225492749frow16_col0 {
#             background-color:  yellow;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_22085ab8_ff9c_11ed_a732_4a225492749frow17_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_22085ab8_ff9c_11ed_a732_4a225492749frow18_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_22085ab8_ff9c_11ed_a732_4a225492749frow19_col0 {
#             background-color:  pink;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_22085ab8_ff9c_11ed_a732_4a225492749frow20_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_22085ab8_ff9c_11ed_a732_4a225492749frow21_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_22085ab8_ff9c_11ed_a732_4a225492749frow22_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_22085ab8_ff9c_11ed_a732_4a225492749frow23_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_22085ab8_ff9c_11ed_a732_4a225492749frow24_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_22085ab8_ff9c_11ed_a732_4a225492749frow25_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }    #T_22085ab8_ff9c_11ed_a732_4a225492749frow26_col0 {
#             background-color:  white;
#             font-weight:  normal;
#             font-style:  normal;
#         }</style><table id="T_22085ab8_ff9c_11ed_a732_4a225492749f" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Amount</th>    </tr>    <tr>        <th class="index_name level0" >Account</th>        <th class="index_name level1" >Cat</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_22085ab8_ff9c_11ed_a732_4a225492749flevel0_row0" class="row_heading level0 row0" rowspan=6>20-53-97 30728691</th>
#                         <th id="T_22085ab8_ff9c_11ed_a732_4a225492749flevel1_row0" class="row_heading level1 row0" >HMRCDD</th>
#                         <td id="T_22085ab8_ff9c_11ed_a732_4a225492749frow0_col0" class="data row0 col0" >-300</td>
#             </tr>
#             <tr>
#                                 <th id="T_22085ab8_ff9c_11ed_a732_4a225492749flevel1_row1" class="row_heading level1 row1" >Mortgage</th>
#                         <td id="T_22085ab8_ff9c_11ed_a732_4a225492749frow1_col0" class="data row1 col0" >-20596</td>
#             </tr>
#             <tr>
#                                 <th id="T_22085ab8_ff9c_11ed_a732_4a225492749flevel1_row2" class="row_heading level1 row2" >OtherExpense</th>
#                         <td id="T_22085ab8_ff9c_11ed_a732_4a225492749frow2_col0" class="data row2 col0" >-8.9</td>
#             </tr>
#             <tr>
#                                 <th id="T_22085ab8_ff9c_11ed_a732_4a225492749flevel1_row3" class="row_heading level1 row3" >OtherIncome</th>
#                         <td id="T_22085ab8_ff9c_11ed_a732_4a225492749frow3_col0" class="data row3 col0" >22355.2</td>
#             </tr>
#             <tr>
#                                 <th id="T_22085ab8_ff9c_11ed_a732_4a225492749flevel1_row4" class="row_heading level1 row4" >OurRent</th>
#                         <td id="T_22085ab8_ff9c_11ed_a732_4a225492749frow4_col0" class="data row4 col0" >0</td>
#             </tr>
#             <tr>
#                                 <th id="T_22085ab8_ff9c_11ed_a732_4a225492749flevel1_row5" class="row_heading level1 row5" >RegularPayment</th>
#                         <td id="T_22085ab8_ff9c_11ed_a732_4a225492749frow5_col0" class="data row5 col0" >-630.25</td>
#             </tr>
#             <tr>
#                         <th id="T_22085ab8_ff9c_11ed_a732_4a225492749flevel0_row6" class="row_heading level0 row6" rowspan=4>20-74-09 40406538</th>
#                         <th id="T_22085ab8_ff9c_11ed_a732_4a225492749flevel1_row6" class="row_heading level1 row6" >OtherExpense</th>
#                         <td id="T_22085ab8_ff9c_11ed_a732_4a225492749frow6_col0" class="data row6 col0" >-0.7</td>
#             </tr>
#             <tr>
#                                 <th id="T_22085ab8_ff9c_11ed_a732_4a225492749flevel1_row7" class="row_heading level1 row7" >OtherIncome</th>
#                         <td id="T_22085ab8_ff9c_11ed_a732_4a225492749frow7_col0" class="data row7 col0" >2546</td>
#             </tr>
#             <tr>
#                                 <th id="T_22085ab8_ff9c_11ed_a732_4a225492749flevel1_row8" class="row_heading level1 row8" >PersonalExpense</th>
#                         <td id="T_22085ab8_ff9c_11ed_a732_4a225492749frow8_col0" class="data row8 col0" >-2084.48</td>
#             </tr>
#             <tr>
#                                 <th id="T_22085ab8_ff9c_11ed_a732_4a225492749flevel1_row9"

# %% [markdown]
# #### Mortgage check
# Check mortgages refunded from business account

# %%
dfMtg=dfAll[((dfAll.Cat=='Mortgage')|(dfAll.Cat=='MortgageRefund'))&(dfAll.Account!='60-83-71 00558156')].groupby(['Account','Cat']).Amount.sum()
dfMtg=dfMtg.reset_index().pivot('Account','Cat')
dfMtg.columns=dfMtg.columns.get_level_values(1)
if('MortgageRefund' not in dfMtg.columns):
    dfMtg['MortgageRefund']=0
dfMtg['Diff']=dfMtg.Mortgage + dfMtg.MortgageRefund
dfMtg
# Out:
# Cat                Mortgage  MortgageRefund      Diff
# Account
# 20-53-97 30728691 -20596.03               0 -20596.03

# %%
dfMtg['Diff'].sum()
# Out:
# -20596.029999999995

# %% [markdown]
# #### Rent check
# Rents going to wrong account

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='OurRent')]
# Out:
#                       Account  Amount     Subcategory  \
# 2023-04-04  20-53-97 30728691  -820.0    Bill Payment
# 2023-04-28  20-53-97 30728691   820.0  Counter Credit
#
#                                                    Memo Property Description  \
# 2023-04-04  RSA CAPITAL LIMITE    MWILLIAMS 196BRENT BB  196BKIN         NaN
# 2023-04-28               M Williams            RENT BGC  196BKIN         NaN
#
#                 Cat Subcat
# 2023-04-04  OurRent    NaN
# 2023-04-28  OurRent    NaN

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='OurRent')].groupby(['Cat']).sum()
# Out:
#          Amount
# Cat
# OurRent     0.0

# %% [markdown]
# #### Property expense check
# Property expenses and service charges taken from 3072 or 6045

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='PropertyExpense')]
# Out:
#                       Account  Amount     Subcategory  \
# 2023-04-28  20-74-09 60458872   -15.0  Standing Order
#
#                                             Memo Property Description  \
# 2023-04-28  SSE SOUTHERN ELECT    6882766014 STO   169FAW         NaN
#
#                         Cat Subcat
# 2023-04-28  PropertyExpense    NaN

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='PropertyExpense')].groupby(['Cat']).sum()
# Out:
#                  Amount
# Cat
# PropertyExpense   -15.0

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='ServiceCharge')]
# Out:
# Empty DataFrame
# Columns: [Account, Amount, Subcategory, Memo, Property, Description, Cat, Subcat]
# Index: []

# %%
dfAll.loc[(dfAll.Account!='60-83-71 00558156')&(dfAll.Cat=='ServiceCharge')].groupby(['Cat']).sum()
# Out:
# Empty DataFrame
# Columns: [Amount]
# Index: []

# %% [markdown]
# ### Reconcile Bank data with Beals data

# %% [markdown]
# - Check Beals cumulative payments
#     - puts credits/debits into a single column and keeps track of cumulative values - a records with an 'Amount payable'
#       with a non-zero value shows records have been carried forward from previous year or are to be carried forward to
#       next.
# - Reconcile Bank payments against Beals
#     - iterate bank data for each payment from Beals, checking for corresponding data in Beals transactions list.
#     - check for Bank records not reconciled to Beals payment
#     - check for Beals records with not corresponding Bank payment
#     - find Beals payments that include a transaction from previous year (identified by non zero cumulative amount)
#     - find Beals transactions that have not been paid for and so are carried forward to next year (reconcile=0 flag)
# - Create output spreadsheets
#     - included is combo ledger of bank payments received along with Beals transactions in order to check balances

# %%
import numpy as np
import pandas as pd

# %%
import time
import os.path
import shutil

def backup_file(filename):
    timestr = time.strftime('%Y%m%d-%H%M%S')
    if os.path.isfile(filename):
        shutil.copy2(filename,filename+'.bak_' + timestr)
    return filename

# %%
#path = 'M:/My Documents/Business/Bugisiw Ltd/TaxReturn/TaxReturn_2020-2021/LLP accounts/'
taxreturn_yr='TaxReturn_2022-2023'
path = 'E:\\dtuklaptop\\e\\Users\\Mat\\python\\data\\property\\'+taxreturn_yr+'\\LLP accounts\\'
startdatestr='2022-04-06'
enddatestr='2022-07-31'

# %%
# Load bank files
#df6=pd.read_csv(path+'6045_s1.csv', parse_dates=['Date'], dayfirst=True)
#df3=pd.read_csv(path+'3072_s1.csv', parse_dates=['Date'], dayfirst=True)
input_file_6045 = path + '6045_categorised.xlsx'
df6=pd.read_excel(input_file_6045,sheet_name='6045')
df6=df6[~df6.Account.isnull()]
input_file_3072 = path + '3072_categorised.xlsx'
df3=pd.read_excel(input_file_3072,sheet_name='3072')
df3=df3[~df3.Account.isnull()]

# %%
# Load Beals transactions
#dfB=pd.read_csv(path+'beals.csv', parse_dates=['Date Created'], dayfirst=True)
dfB=pd.read_excel(path+'beals.xlsx', sheet_name='beals', parse_dates=['Date Created'], dayfirst=True)
dfB.insert(0,'Date', dfB['Date Created'].dt.date)
dfB=dfB.sort_values(by=['ID','Date Created'])
dfB['Date'] =  pd.to_datetime(dfB.Date)
#dfB['Item Description'] = dfB.ID + ': ' + dfB['Item Description']

# %%
startdate = pd.to_datetime(startdatestr).date()
enddate = pd.to_datetime(enddatestr).date()
dfB=dfB[(dfB.Date >= startdate)&(dfB.Date <= enddate)]
df6=df6[(df6.Date >= startdate)&(df6.Date <= enddate)]
df3=df3[(df3.Date >= startdate)&(df3.Date <= enddate)]
# Out:
# C:\Users\MSTDTP21\.conda\envs\mtpython36\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\MSTDTP21\.conda\envs\mtpython36\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   after removing the cwd from sys.path.
# C:\Users\MSTDTP21\.conda\envs\mtpython36\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   """

# %% [markdown]
# ### Add cumulative payments to Beals transactions
# - it's easier to see missing transacations when there is a cumulative figure

# %%
# Create amount column
for index, row in dfB.iterrows():
    if(row['Credit Amount']>0):
        dfB.at[index,'Amount']=-round(row['Credit Amount'],2)
    elif(row['Debit Amount']>0):
        dfB.at[index,'Amount']=round(row['Debit Amount'],2)

# %%
# Track cumulative amounts between payments
cumamount=0.0;
lastID=''
for index, row in dfB.iterrows():
    if(row.ID != lastID):
        cumamount=row.Amount
    else:
        cumamount=cumamount + row.Amount

    dfB.at[index,'CumAmount'] = round(cumamount,2)
    if('Amount payable' in row['Item Description']):
        cumamount=0.0
    lastID=row.ID

# %% [markdown]
# ### Reconcile Bank payments against Beals

# %% [markdown]
# Iterate bank data for each payment from Beals, checking for corresponding data in Beals transactions list.
#
# Mark reconciled data in bank and reconciled Beals payments with 1, mark Beals transactions with account they were paid into.

# %%
from datetime import datetime, timedelta

def find_last_rent_received(payment_index, property_code, df_beals):
    rec=df_beals[(df_beals.ID==property_code)&(df_beals['Item Description'].str.contains('Rent for period'))&(df_beals.index<payment_index)]
    if not rec.empty:
        return rec['Item Description'].iloc[-1]
    else:
        return 'NOT FOUND'

def reconcile_bank_with_beals(df_bank, df_beals,bank_label):
    lookback = 6
    errorcount = 0
    for index, row in df_bank[df_bank['Memo'].str.contains("BEALS ESTATE AGENT", na=False)].iterrows():
        # Lookback 5 days for payment to appear in Beals statement
        print('Reconciling ' + str(row.Date) + ' ' + row.Memo + ' ' + str(row.Amount))

        startdate = row.Date - timedelta(days=lookback)
        enddate = row.Date
        rec=df_beals.loc[(df_beals['ID']==row.Property)&(df_beals['Debit Amount']==row.Amount)&(df_beals['Date']>=startdate)&(df_beals['Date']<=enddate)&(df_beals.ReconciledBank!=1)]
        if not rec.empty:
            print( str(rec.iloc[0].name)+' With '+ str(rec.Date.iloc[0]) + ' ' + rec['Item Description'].iloc[0] + ' ' + str(rec['Debit Amount'].iloc[0]))
            df_bank.at[index, 'ReconciledBeals']=1
            df_bank.at[index, 'Description']=find_last_rent_received(rec.iloc[0].name,row.Property,df_beals)
            df_beals.at[rec.iloc[0].name, 'ReconciledBank']=1
            df_beals.at[rec.iloc[0].name, 'ReconciledBankAccount']=bank_label
        else:
            print('CANNOT RECONCILE')
            errorcount = errorcount + 1

    print('Errors=' +  str(errorcount))

# %%
df6.loc[df6['Memo'].str.contains("BEALS ESTATE AGENT", na=False),'ReconciledBeals']=0
df3.loc[df3['Memo'].str.contains("BEALS ESTATE AGENT", na=False),'ReconciledBeals']=0
dfB['ReconciledBank']=np.nan
dfB['ReconciledBankAccount']=np.nan

# %% [markdown]
# #### Reconcile 6045 with Beals

# %%
reconcile_bank_with_beals(df6,dfB,6045)
# Out:
# Reconciling 2022-04-07 00:00:00 BEALS ESTATE AGENT    196A KINGSTON ROAD BGC 470.32
# CANNOT RECONCILE
# Reconciling 2022-04-08 00:00:00 BEALS ESTATE AGENT    FLAT 1412-14 ALHAM BGC 452.0
# 12 With 2022-04-06 00:00:00 Amount payable to Mr Mathew Tucker - Flat 14, 12-14 Alhambra Road, Southsea 452.0
# Reconciling 2022-04-11 00:00:00 BEALS ESTATE AGENT    FLAT 2171 FAWCETT  BGC 416.76
# 34 With 2022-04-07 00:00:00 Amount payable to Mr Mathew Tucker - Flat 2, 171 Fawcett Road, Southsea 416.76
# Reconciling 2022-04-11 00:00:00 BEALS ESTATE AGENT    FLAT 3163 FRATTON  BGC 151.74
# 56 With 2022-04-07 00:00:00 Amount payable to Mr Mathew Tucker - Flat 3, 163 Fratton Road, Portsmouth 151.74
# Reconciling 2022-04-11 00:00:00 BEALS ESTATE AGENT    FLAT 1012-14 ALHAM BGC 205.7
# 5 With 2022-04-07 00:00:00 Amount payable to Mr Mathew Tucker - Flat 10, 12-14 Alhambra Road, Southsea 205.7
# Reconciling 2022-04-11 00:00:00 BEALS ESTATE AGENT    FLAT 1169 FAWCETT  BGC 420.96
# 40 With 2022-04-07 00:00:00 Amount payable to Mr Mathew Tucker - Flat 1, 169 Fawcett Road, Southsea 420.96
# Reconciling 2022-04-11 00:00:00 BEALS ESTATE AGENT    FLAT 712-14 ALHAMB BGC 206.15
# 63 With 2022-04-07 00:00:00 Amount payable to Mr Mathew Tucker - Flat 7, 12-14 Alhambra Road, Southsea 206.15
# Reconciling 2022-04-12 00:00:00 BEALS ESTATE AGENT    FLAT 68 ALHAMBRA R BGC 452.0
# 52 With 2022-04-08 00:00:00 Amount payable to Mr Mathew Tucker - Flat 6, 8 Alhambra Road, Southsea 452.0
# Reconciling 2022-04-13 00:00:00 BEALS ESTATE AGENT    FLAT 1171 FAWCETT  BGC 635.2
# 72 With 2022-04-11 00:00:00 Amount payable to Mr Mathew Tucker - Flat 1, 171 Fawcett Road, Southsea 635.2
# Reconciling 2022-04-14 00:00:00 BEALS ESTATE AGENT    FLAT 616-18 ALHAMB BGC 416.75
# 19 With 2022-04-12 00:00:00 Amount payable to Mr Mathew Tucker - Flat 6, 16-18 Alhambra Road, Southsea 416.75
# Reconciling 2022-04-14 00:00:00 BEALS ESTATE AGENT    SHOP196 KINGSTON R BGC 314.6
# 44 With 2022-04-12 00:00:00 Amount payable to Mr Mathew Tucker - Shop, 196 Kingston Road, Portsmouth 314.6
# Reconciling 2022-04-19 00:00:00 BEALS ESTATE AGENT    FLAT 712-14 ALHAMB BGC 210.61
# 66 With 2022-04-14 00:00:00 Amount payable to Mr Mathew Tucker - Flat 7, 12-14 Alhambra Road, Southsea 210.61
# Reconciling 2022-04-19 00:00:00 BEALS ESTATE AGENT    FLAT 1116-18 ALHAM BGC 497.8
# 23 With 2022-04-13 00:00:00 Amount payable to Mr Mathew Tucker - Flat 11, 16-18 Alhambra Road, Southsea 497.8
# Reconciling 2022-04-19 00:00:00 BEALS ESTATE AGENT    FLAT 3163 FRATTON  BGC 222.78
# 59 With 2022-04-14 00:00:00 Amount payable to Mr Mathew Tucker - Flat 3, 163 Fratton Road, Portsmouth 222.78
# Reconciling 2022-04-22 00:00:00 BEALS ESTATE AGENT    FLAT 1012-14 ALHAM BGC 211.04
# 8 With 2022-04-20 00:00:00 Amount payable to Mr Mathew Tucker - Flat 10, 12-14 Alhambra Road, Southsea 211.04
# Reconciling 2022-04-28 00:00:00 BEALS ESTATE AGENT    FLAT 1321 LONDON R BGC 446.0
# 27 With 2022-04-26 00:00:00 Amount payable to Mr Mathew Tucker - Flat 1, 321 London Road, Portsmouth 446.0
# Reconciling 2022-05-06 00:00:00 BEALS ESTATE AGENT    196A KINGSTON ROAD BGC 470.32
# 148 With 2022-05-04 00:00:00 Amount payable to Mr Mathew Tucker - 196a Kingston Road, Portsmouth 470.32
# Reconciling 2022-05-09 00:00:00 BEALS ESTATE AGENT    FLAT 1412-14 ALHAM BGC 452.0
# 111 With 2022-05-06 00:00:00 Amount payable to Mr Mathew Tucker - Flat 14, 12-14 Alhambra Road, Southsea 452.0
# Reconciling 2022-05-12 00:00:00 BEALS ESTATE AGENT    FLAT 68 ALHAMBRA R BGC 452.0
# 152 With 2022-05-10 00:00:00 Amount payable to Mr Mathew Tucker - Flat 6, 8 Alhambra Road, Southsea 452.0
# Reconciling 2022-05-12 00:00:00 BEALS ESTATE AGENT    FLAT 1169 FAWCETT  BGC 420.97
# 140 With 2022-05-10 00:00:00 Amount payable to Mr Mathew Tucker - Flat 1, 169 Fawcett Road, Southsea 420.97
# Reconciling 2022-05-12 00:00:00 BEALS ESTATE AGENT    FLAT 2171 FAWCETT  BGC 416.75
# 134 With 2022-05-10 00:00:00 Amount payable to Mr Mathew Tucker - Flat 2, 171 Fawcett Road, Southsea 416.75
# Reconciling 2022-05-12 00:00:00 BEALS ESTATE AGENT    FLAT 712-14 ALHAMB BGC 241.39
# 163 With 2022-05-10 00:00:00 Amount payable to Mr Mathew Tucker - Flat 7, 12-14 Alhambra Road, Southsea 241.39
# Reconciling 2022-05-12 00:00:00 BEALS ESTATE AGENT    FLAT 1012-14 ALHAM BGC 240.96
# 104 With 2022-05-10 00:00:00 Amount payable to Mr Mathew Tucker - Flat 10, 12-14 Alhambra Road, Southsea 240.96
# Reconciling 2022-05-12 00:00:00 BEALS ESTATE AGENT    FLAT 3163 FRATTON  BGC 183.42
# 156 With 2022-05-10 00:00:00 Amount payable to Mr Mathew Tucker - Flat 3, 163 Fratton Road, Portsmouth 183.42
# Reconciling 2022-05-12 00:00:00 BEALS ESTATE AGENT    FLAT 616-18 ALHAMB BGC 67.32
# 116 With 2022-05-10 00:00:00 Amount payable to Mr Mathew Tucker - Flat 6, 16-18 Alhambra Road, Southsea 67.32
# Reconciling 2022-05-13 00:00:00 BEALS ESTATE AGENT    FLAT 1171 FAWCETT  BGC 635.2
# 172 With 2022-05-11 00:00:00 Amount payable to Mr Mathew Tucker - Flat 1, 171 Fawcett Road, Southsea 635.2
# Reconciling 2022-05-16 00:00:00 BEALS ESTATE AGENT    FLAT 616-18 ALHAMB BGC 349.44
# 119 With 2022-05-12 00:00:00 Amount payable to Mr Mathew Tucker - Flat 6, 16-18 Alhambra Road, Southsea 349.44
# Reconciling 2022-05-16 00:00:00 BEALS ESTATE AGENT    SHOP196 KINGSTON R BGC 314.6
# 144 With 2022-05-12 00:00:00 Amount payable to Mr Mathew Tucker - Shop, 196 Kingston Road, Portsmouth 314.6
# Reconciling 2022-05-17 00:00:00 BEALS ESTATE AGENT    FLAT 1116-18 ALHAM BGC 497.8
# 123 With 2022-05-13 00:00:00 Amount payable to Mr Mathew Tucker - Flat 11, 16-18 Alhambra Road, Southsea 497.8
# Reconciling 2022-05-17 00:00:00 BEALS ESTATE AGENT    FLAT 3163 FRATTON  BGC 191.08
# 159 With 2022-05-14 00:00:00 Amount payable to Mr Mathew Tucker - Flat 3, 163 Fratton Road, Portsmouth 191.08
# Reconciling 2022-05-17 00:00:00 BEALS ESTATE AGENT    FLAT 712-14 ALHAMB BGC 175.36
# 166 With 2022-05-14 00:00:00 Amount payable to Mr Mathew Tucker - Flat 7, 12-14 Alhambra Road, Southsea 175.36
# Reconciling 2022-05-24 00:00:00 BEALS ESTATE AGENT    FLAT 1012-14 ALHAM BGC 175.8
# 107 With 2022-05-20 00:00:00 Amount payable to Mr Mathew Tucker - Flat 10, 12-14 Alhambra Road, Southsea 175.8
# Reconciling 2022-05-27 00:00:00 BEALS ESTATE AGENT    FLAT 1321 LONDON R BGC 446.0
# 127 With 2022-05-25 00:00:00 Amount payable to Mr Mathew Tucker - Flat 1, 321 London Road, Portsmouth 446.0
# Reconciling 2022-06-06 00:00:00 BEALS ESTATE AGENT    	FLAT 712-14 ALHAMB BG 276.64
# 288 With 2022-06-01 00:00:00 Amount payable to Mr Mathew Tucker - Flat 7, 12-14 Alhambra Road, Southsea 276.64
# Reconciling 2022-06-06 00:00:00 BEALS ESTATE AGENT    	FLAT 1169 FAWCETT BGC 418.36
# 259 With 2022-06-01 00:00:00 Amount payable to Mr Mathew Tucker - Flat 1, 169 Fawcett Road, Southsea 418.36
# Reconciling 2022-06-06 00:00:00 BEALS ESTATE AGENT    	FLAT 3163 FRATTON BGC 215.12
# 278 With 2022-06-01 00:00:00 Amount payable to Mr Mathew Tucker - Flat 3, 163 Fratton Road, Portsmouth 215.12
# Reconciling 2022-06-06 00:00:00 BEALS ESTATE AGENT    	FLAT 2171 FAWCETT BGC 206.15
# 249 With 2022-06-01 00:00:00 Amount payable to Mr Mathew Tucker - Flat 2, 171 Fawcett Road, Southsea 206.15
# Reconciling 2022-06-06 00:00:00 BEALS ESTATE AGENT    	FLAT 616-18 ALHAMB BG 102.56
# 230 With 2022-06-01 00:00:00 Amount payable to Mr Mathew Tucker - Flat 6, 16-18 Alhambra Road, Southsea 102.56
# Reconciling 2022-06-06 00:00:00 BEALS ESTATE AGENT    	FLAT 1012-14 ALHAM BG 276.2
# 215 With 2022-06-01 00:00:00 Amount payable to Mr Mathew Tucker - Flat 10, 12-14 Alhambra Road, Southsea 276.2
# Reconciling 2022-06-08 00:00:00 BEALS ESTATE AGENT    	196A KINGSTON ROAD BG 470.32
# 270 With 2022-06-06 00:00:00 Amount payable to Mr Mathew Tucker - 196a Kingston Road, Portsmouth 470.32
# Reconciling 2022-06-08 00:00:00 BEALS ESTATE AGENT    	FLAT 2171 FAWCETT BGC 210.61
# 252 With 2022-06-06 00:00:00 Amount payable to Mr Mathew Tucker - Flat 2, 171 Fawcett Road, Southsea 210.61
# Reconciling 2022-06-08 00:00:00 BEALS ESTATE AGENT    	FLAT 1412-14 ALHAM BG 452.0
# 225 With 2022-06-06 00:00:00 Amount payable to Mr Mathew Tucker - Flat 14, 12-14 Alhambra Road, Southsea 452.0
# Reconciling 2022-06-10 00:00:00 BEALS ESTATE AGENT    	FLAT 68 ALHAMBRA R BG 433.49
# 274 With 2022-06-08 00:00:00 Amount payable to Mr Mathew Tucker - Flat 6, 8 Alhambra Road, Southsea 433.49
# Reconciling 2022-06-13 00:00:00 BEALS ESTATE AGENT    	FLAT 1171 FAWCETT BGC 635.2
# 302 With 2022-06-09 00:00:00 Amount payable to Mr Mathew Tucker - Flat 1, 171 Fawcett Road, Southsea 635.2
# Reconciling 2022-06-15 00:00:00 BEALS ESTATE AGENT    	FLAT 616-18 ALHAMB BG 314.19
# 233 With 2022-06-13 00:00:00 Amount payable to Mr Mathew Tucker - Flat 6, 16-18 Alhambra Road, Southsea 314.19
# Reconciling 2022-06-16 00:00:00 BEALS ESTATE AGENT    	FLAT 1116-18 ALHAM BG 497.8
# 240 With 2022-06-14 00:00:00 Amount payable to Mr Mathew Tucker - Flat 11, 16-18 Alhambra Road, Southsea 497.8
# Reconciling 2022-06-16 00:00:00 BEALS ESTATE AGENT    	FLAT 3163 FRATTON BGC 159.38
# 281 With 2022-06-14 00:00:00 Amount payable to Mr Mathew Tucker - Flat 3, 163 Fratton Road, Portsmouth 159.38
# Reconciling 2022-06-16 00:00:00 BEALS ESTATE AGENT    	FLAT 712-14 ALHAMB BG 140.11
# 291 With 2022-06-14 00:00:00 Amount payable to Mr Mathew Tucker - Flat 7, 12-14 Alhambra Road, Southsea 140.11
# Reconciling 2022-06-16 00:00:00 BEALS ESTATE AGENT    	SHOP196 KINGSTON R BG 314.6
# 266 With 2022-06-14 00:00:00 Amount payable to Mr Mathew Tucker - Shop, 196 Kingston Road, Portsmouth 314.6
# Reconciling 2022-06-23 00:00:00 BEALS ESTATE AGENT    	FLAT 1012-14 ALHAM BG 140.55
# 218 With 2022-06-21 00:00:00 Amount payable to Mr Mathew Tucker - Flat 10, 12-14 Alhambra Road, Southsea 140.55
# Reconciling 2022-06-28 00:00:00 BEALS ESTATE AGENT    	FLAT 1321 LONDON R BG 446.0
# 244 With 2022-06-25 00:00:00 Amount payable to Mr Mathew Tucker - Flat 1, 321 London Road, Portsmouth 446.0
# Reconciling 2022-06-30 00:00:00 BEALS ESTATE AGENT    	FLAT 2171 FAWCETT BGC 241.39
# 256 With 2022-06-28 00:00:00 Amount payable to Mr Mathew Tucker - Flat 2, 171 Fawcett Road, Southsea 241.39
# Reconciling 2022-06-30 00:00:00 BEALS ESTATE AGENT    	FLAT 712-14 ALHAMB BG 311.89
# 295 With 2022-06-28 00:00:00 Amount payable to Mr Mathew Tucker - Flat 7, 12-14 Alhambra Road, Southsea 311.89
# Reconciling 2022-06-30 00:00:00 BEALS ESTATE AGENT    	FLAT 616-18 ALHAMB BG 137.81
# 237 With 2022-06-28 00:00:00 Amount payable to Mr Mathew Tucker - Flat 6, 16-18 Alhambra Road, Southsea 137.81
# Reconciling 2022-06-30 00:00:00 BEALS ESTATE AGENT    	FLAT 1169 FAWCETT BGC 423.56
# 263 With 2022-06-28 00:00:00 Amount payable to Mr Mathew Tucker - Flat 1, 169 Fawcett Road, Southsea 423.56
# Reconciling 2022-06-30 00:00:00 BEALS ESTATE AGENT    	FLAT 3163 FRATTON BGC 246.82
# 285 With 2022-06-28 00:00:00 Amount payable to Mr Mathew Tucker - Flat 3, 163 Fratton Road, Portsmouth 246.82
# Reconciling 2022-06-30 00:00:00 BEALS ESTATE AGENT    	FLAT 1012-14 ALHAM BG 311.45
# 222 With 2022-06-28 00:00:00 Amount payable to Mr Mathew Tucker - Flat 10, 12-14 Alhambra Road, Southsea 311.45
# Reconciling 2022-07-06 00:00:00 BEALS ESTATE AGENT    	FLAT 2171 FAWCETT BGC 175.36
# 372 With 2022-07-04 00:00:00 Amount payable to Mr Mathew Tucker - Flat 2, 171 Fawcett Road, Southsea 175.36
# Reconciling 2022-07-07 00:00:00 BEALS ESTATE AGENT    	196A KINGSTON ROAD BG 470.32
# 389 With 2022-07-05 00:00:00 Amount payable to Mr Mathew Tucker - 196a Kingston Road, Portsmouth 470.32
# Reconciling 2022-07-08 00:00:00 BEALS ESTATE AGENT    	FLAT 1412-14 ALHAM BG 452.0
# 353 With 2022-07-06 00:00:00 Amount payable to Mr Mathew Tucker - Flat 14, 12-14 Alhambra Road, Southsea 452.0
# Reconciling 2022-07-12 00:00:00 BEALS ESTATE AGENT    	FLAT 68 ALHAMBRA R BG 416.76
# 395 With 2022-07-08 00:00:00 Amount payable to Mr Mathew Tucker - Flat 6, 8 Alhambra Road, Southsea 416.76
# Reconciling 2022-07-13 00:00:00 BEALS ESTATE AGENT    	FLAT 1171 FAWCETT BGC 635.2
# 418 With 2022-07-11 00:00:00 Amount payable to Mr Mathew Tucker - Flat 1, 171 Fawcett Road, Southsea 635.2
# Reconciling 2022-07-14 00:00:00 BEALS ESTATE AGENT    	FLAT 616-18 ALHAMB BG 278.94
# 357 With 2022-07-12 00:00:00 Amount payable to Mr Mathew Tucker - Flat 6, 16-18 Alhambra Road, Southsea 278.94
# Reconciling 2022-07-14 00:00:00 BEALS ESTATE AGENT    	SHOP196 KINGSTON R BG 314.6
# 385 With 2022-07-12 00:00:00 Amount payable to Mr Mathew Tucker - Shop, 196 Kingston Road, Portsmouth 314.6
# Reconciling 2022-07-15 00:00:00 BEALS ESTATE AGENT    	FLAT 1116-18 ALHAM BG 497.8
# 364 With 2022-07-13 00:00:00 Amount payable to Mr Mathew Tucker - Flat 11, 16-18 Alhambra Road, Southsea 497.8
# Reconciling 2022-07-18 00:00:00 BEALS ESTATE AGENT    	FLAT 712-14 ALHAMB BG 104.87
# 409 With 2022-07-14 00:00:00 Amount payable to Mr Mathew Tucker - Flat 7, 12-14 Alhambra Road, Southsea 104.87
# Reconciling 2022-07-19 00:00:00 BEALS ESTATE AGENT    	FLAT 3163 FRATTON BGC 127.69
# 402 With 2022-07-15 00:00:00 Amount payable to Mr Mathew Tucker - Flat 3, 163 Fratton Road, Portsmouth 127.69
# Reconciling 2022-07-22 00:00:00 BEALS ESTATE AGENT    	FLAT 1012-14 ALHAM BG 105.3
# 346 With 2022-07-20 00:00:00 Amount payable to Mr Mathew Tucker - Flat 10, 12-14 Alhambra Road, Southsea 105.3
# Reconciling 2022-07-28 00:00:00 BEALS ESTATE AGENT    	FLAT 2171 FAWCETT BGC 282.64
# 375 With 2022-07-26 00:00:00 Amount payable to Mr Mathew Tucker - Flat 2, 171 Fawcett Road, Southsea 282.64
# Reconciling 2022-07-28 00:00:00 BEALS ESTATE AGENT    	FLAT 1321 LONDON R BG 446.0
# 368 With 2022-07-26 00:00:00 Amount payable to Mr Mathew Tucker - Flat 1, 321 London Road, Portsmouth 446.0
# Reconciling 2022-07-28 00:00:00 BEALS ESTATE AGENT    	FLAT 1012-14 ALHAM BG 352.7
# 349 With 2022-07-26 00:00:00 Amount payable to Mr Mathew Tucker - Flat 10, 12-14 Alhambra Road, Southsea 352.7
# Reconciling 2022-07-28 00:00:00 BEALS ESTATE AGENT    	FLAT 616-18 ALHAMB BG 179.06
# 360 With 2022-07-26 00:00:00 Amount payable to Mr Mathew Tucker - Flat 6, 16-18 Alhambra Road, Southsea 179.06
# Reconciling 2022-07-28 00:00:00 BEALS ESTATE AGENT    	FLAT 712-14 ALHAMB BG 353.13
# 412 With 2022-07-26 00:00:00 Amount payable to Mr Mathew Tucker - Flat 7, 12-14 Alhambra Road, Southsea 353.13
# Reconciling 2022-07-28 00:00:00 BEALS ESTATE AGENT    	FLAT 1169 FAWCETT BGC 426.97
# 381 With 2022-07-26 00:00:00 Amount payable to Mr Mathew Tucker - Flat 1, 169 Fawcett Road, Southsea 426.97
# Reconciling 2022-07-28 00:00:00 BEALS ESTATE AGENT    	FLAT 3163 FRATTON BGC 284.51
# 405 With 2022-07-26 00:00:00 Amount payable to Mr Mathew Tucker - Flat 3, 163 Fratton Road, Portsmouth 284.51
# Errors=1

# %% [markdown]
# #### Reconcile 3072 with Beals

# %%
reconcile_bank_with_beals(df3,dfB,3072)
# Out:
# Reconciling 2022-04-07 00:00:00 BEALS ESTATE AGENT    FLAT 78 ALHAMBRA R BGC 452.0
# CANNOT RECONCILE
# Reconciling 2022-04-11 00:00:00 BEALS ESTATE AGENT    FLAT 1216-18 ALHAM BGC 136.27
# 93 With 2022-04-07 00:00:00 Amount payable to Ms Ivana Valentino - Flat 12, 16-18 Alhambra Road, Southsea 136.27
# Reconciling 2022-04-11 00:00:00 BEALS ESTATE AGENT    FLAT 512-14 ALHAMB BGC 200.06
# 80 With 2022-04-07 00:00:00 Amount payable to Ms Ivana Valentino - Flat 5, 12-14 Alhambra Road, Southsea 200.06
# Reconciling 2022-04-11 00:00:00 BEALS ESTATE AGENT    FLAT 1612-14 ALHAM BGC 422.29
# 89 With 2022-04-07 00:00:00 Amount payable to Ms Ivana Valentino - Flat 16, 12-14 Alhambra Road, Southsea 422.29
# Reconciling 2022-04-22 00:00:00 BEALS ESTATE AGENT    FLAT 1216-18 ALHAM BGC 284.74
# 96 With 2022-04-20 00:00:00 Amount payable to Ms Ivana Valentino - Flat 12, 16-18 Alhambra Road, Southsea 284.74
# Reconciling 2022-04-27 00:00:00 BEALS ESTATE AGENT    FLAT 512-14 ALHAMB BGC 208.26
# 83 With 2022-04-23 00:00:00 Amount payable to Ms Ivana Valentino - Flat 5, 12-14 Alhambra Road, Southsea 208.26
# Reconciling 2022-05-06 00:00:00 BEALS ESTATE AGENT    FLAT 78 ALHAMBRA R BGC 452.0
# 176 With 2022-05-04 00:00:00 Amount payable to Ms Ivana Valentino - Flat 7, 8 Alhambra Road, Southsea 452.0
# Reconciling 2022-05-12 00:00:00 BEALS ESTATE AGENT    FLAT 1612-14 ALHAM BGC 422.29
# 200 With 2022-05-10 00:00:00 Amount payable to Ms Ivana Valentino - Flat 16, 12-14 Alhambra Road, Southsea 422.29
# Reconciling 2022-05-12 00:00:00 BEALS ESTATE AGENT    FLAT 512-14 ALHAMB BGC 234.58
# 184 With 2022-05-10 00:00:00 Amount payable to Ms Ivana Valentino - Flat 5, 12-14 Alhambra Road, Southsea 234.58
# Reconciling 2022-05-12 00:00:00 BEALS ESTATE AGENT    FLAT 1216-18 ALHAM BGC 171.84
# 204 With 2022-05-10 00:00:00 Amount payable to Ms Ivana Valentino - Flat 12, 16-18 Alhambra Road, Southsea 171.84
# Reconciling 2022-05-23 00:00:00 BEALS ESTATE AGENT    FLAT 1216-18 ALHAM BGC 249.16
# 207 With 2022-05-19 00:00:00 Amount payable to Ms Ivana Valentino - Flat 12, 16-18 Alhambra Road, Southsea 249.16
# Reconciling 2022-05-26 00:00:00 BEALS ESTATE AGENT    FLAT 512-14 ALHAMB BGC 173.74
# 187 With 2022-05-24 00:00:00 Amount payable to Ms Ivana Valentino - Flat 5, 12-14 Alhambra Road, Southsea 173.74
# Reconciling 2022-06-06 00:00:00 BEALS ESTATE AGENT    	FLAT 312-14 ALHAMB BG 196.16
# 181 With 2022-05-31 00:00:00 Amount payable to Ms Ivana Valentino 196.16
# Reconciling 2022-06-06 00:00:00 BEALS ESTATE AGENT    	FLAT 312-14 ALHAMB BG 328.84
# 179 With 2022-05-31 00:00:00 Amount payable to Ms Ivana Valentino 328.84
# Reconciling 2022-06-06 00:00:00 BEALS ESTATE AGENT    	FLAT 1612-14 ALHAM BG 422.3
# 324 With 2022-06-01 00:00:00 Amount payable to Ms Ivana Valentino - Flat 16, 12-14 Alhambra Road, Southsea 422.3
# Reconciling 2022-06-06 00:00:00 BEALS ESTATE AGENT    	FLAT 512-14 ALHAMB BG 269.1
# 312 With 2022-06-01 00:00:00 Amount payable to Ms Ivana Valentino - Flat 5, 12-14 Alhambra Road, Southsea 269.1
# Reconciling 2022-06-06 00:00:00 BEALS ESTATE AGENT    	FLAT 1216-18 ALHAM BG 207.42
# 335 With 2022-06-01 00:00:00 Amount payable to Ms Ivana Valentino - Flat 12, 16-18 Alhambra Road, Southsea 207.42
# Reconciling 2022-06-08 00:00:00 BEALS ESTATE AGENT    	FLAT 78 ALHAMBRA R BG 452.0
# 306 With 2022-06-06 00:00:00 Amount payable to Ms Ivana Valentino - Flat 7, 8 Alhambra Road, Southsea 452.0
# Reconciling 2022-06-23 00:00:00 BEALS ESTATE AGENT    	FLAT 1216-18 ALHAM BG 213.59
# 338 With 2022-06-21 00:00:00 Amount payable to Ms Ivana Valentino - Flat 12, 16-18 Alhambra Road, Southsea 213.59
# Reconciling 2022-06-27 00:00:00 BEALS ESTATE AGENT    	FLAT 512-14 ALHAMB BG 139.23
# 315 With 2022-06-23 00:00:00 Amount payable to Ms Ivana Valentino - Flat 5, 12-14 Alhambra Road, Southsea 139.23
# Reconciling 2022-06-30 00:00:00 BEALS ESTATE AGENT    	FLAT 1216-18 ALHAM BG 242.99
# 342 With 2022-06-28 00:00:00 Amount payable to Ms Ivana Valentino - Flat 12, 16-18 Alhambra Road, Southsea 242.99
# Reconciling 2022-06-30 00:00:00 BEALS ESTATE AGENT    	FLAT 1612-14 ALHAM BG 422.29
# 330 With 2022-06-28 00:00:00 Amount payable to Ms Ivana Valentino - Flat 16, 12-14 Alhambra Road, Southsea 422.29
# Reconciling 2022-06-30 00:00:00 BEALS ESTATE AGENT    	FLAT 512-14 ALHAMB BG 303.61
# 319 With 2022-06-28 00:00:00 Amount payable to Ms Ivana Valentino - Flat 5, 12-14 Alhambra Road, Southsea 303.61
# Reconciling 2022-07-07 00:00:00 BEALS ESTATE AGENT    	FLAT 78 ALHAMBRA R BG 452.0
# 442 With 2022-07-05 00:00:00 Amount payable to Ms Ivana Valentino - Flat 7, 8 Alhambra Road, Southsea 452.0
# Reconciling 2022-07-21 00:00:00 BEALS ESTATE AGENT    	FLAT 1216-18 ALHAM BG 178.01
# 422 With 2022-07-19 00:00:00 Amount payable to Ms Ivana Valentino - Flat 12, 16-18 Alhambra Road, Southsea 178.01
# Reconciling 2022-07-26 00:00:00 BEALS ESTATE AGENT    	FLAT 512-14 ALHAMB BG 104.72
# 435 With 2022-07-23 00:00:00 Amount payable to Ms Ivana Valentino - Flat 5, 12-14 Alhambra Road, Southsea 104.72
# Reconciling 2022-07-28 00:00:00 BEALS ESTATE AGENT    	FLAT 1216-18 ALHAM BG 284.57
# 425 With 2022-07-26 00:00:00 Amount payable to Ms Ivana Valentino - Flat 12, 16-18 Alhambra Road, Southsea 284.57
# Reconciling 2022-07-28 00:00:00 BEALS ESTATE AGENT    	FLAT 1612-14 ALHAM BG 428.28
# 431 With 2022-07-26 00:00:00 Amount payable to Ms Ivana Valentino - Flat 16, 12-14 Alhambra Road, Southsea 428.28
# Reconciling 2022-07-28 00:00:00 BEALS ESTATE AGENT    	FLAT 512-14 ALHAMB BG 344.12
# 438 With 2022-07-26 00:00:00 Amount payable to Ms Ivana Valentino - Flat 5, 12-14 Alhambra Road, Southsea 344.12
# Errors=1

# %% [markdown]
# #### Tidy reconciliation flag

# %%
# Backfill reconciliation flag so we know what bank account all Beals transactions relate to
dfB['ReconciledBank'] = dfB.groupby('ID')['ReconciledBank'].bfill()
dfB['ReconciledBank'].fillna(value=0, inplace=True)
dfB['ReconciledBankAccount'] = dfB.groupby('ID')['ReconciledBankAccount'].bfill()
dfB['ReconciledBankAccount'] = dfB.groupby('ID')['ReconciledBankAccount'].ffill()

# %% [markdown]
# #### Error check - Bank transactions not reconciled to Beals Payments
#
# - check Beals data is complete if there are bank payments without a Beals record

# %%
df6.loc[(df6['Memo'].str.contains("BEALS ESTATE AGENT"))&(df6.ReconciledBeals==0)]
# Out:
#         Date            Account  Amount Subcategory  \
# 6 2022-04-07  20-74-09 60458872  470.32   DIRECTDEP
#
#                                            Memo Property Description  \
# 6  BEALS ESTATE AGENT    196A KINGSTON ROAD BGC  196AKIN         NaN
#
#             Category  ReconciledBeals
# 6  BealsRentalIncome              0.0

# %%
df3.loc[(df3['Memo'].str.contains("BEALS ESTATE AGENT"))&(df3.ReconciledBeals==0)]
# Out:
#         Date            Account  Amount Subcategory  \
# 1 2022-04-07  20-53-97 30728691   452.0   DIRECTDEP
#
#                                            Memo Property Description  \
# 1  BEALS ESTATE AGENT    FLAT 78 ALHAMBRA R BGC   F78ALH         NaN
#
#             Category  ReconciledBeals
# 1  BealsRentalIncome              0.0

# %% [markdown]
# #### Error check - Beals Payments not reconciled to Bank transaction - BEALS SAID THEY PAID BUT NOTHING RECEIVED
# - there could be Beals payments at end of year which were paid into bank after year end
# - need to contact Beals if there payments on other dates

# %%
dfB.loc[(dfB['Item Description'].str.contains("Amount payable"))&(dfB['Item Description'].str.contains("Tucker"))&(dfB.ReconciledBank==0)]
# Out:
#           Date      ID  Activity I D        Date Created  \
# 399 2022-07-28  F68ALH        903833 2022-07-28 11:32:00
#
#                                       Item Description Document Type  \
# 399  Amount payable to Mr Mathew Tucker - Flat 6, 8...     Statement
#
#      Document Number  Debit Amount  Credit Amount ID Check  Amount  CumAmount  \
# 399           271665         47.75            0.0       PM   47.75        0.0
#
#      ReconciledBank  ReconciledBankAccount
# 399             0.0                 6045.0

# %%
dfB.loc[(dfB['Item Description'].str.contains("Amount payable"))&(dfB['Item Description'].str.contains("Valentino"))&(dfB.ReconciledBank==0)]
# Out:
# Empty DataFrame
# Columns: [Date, ID, Activity I D, Date Created, Item Description, Document Type, Document Number, Debit Amount, Credit Amount, ID Check, Amount, CumAmount, ReconciledBank, ReconciledBankAccount]
# Index: []

# %% [markdown]
# #### Payments for Beals transactions from previous year

# %% [markdown]
# This section works on the idea that when an amount is payed from Beals ("Amount payable"), this payment should clear the cumulative amount back to 0. If it is not 0, then there is something that might need looking at.
#
# The dates on below transactions should all be around start of period. The cumulative amounts of £6 indicate Legislation & Compliance charges in previous period but paid for in this period. Dates later in year can indicate missing data in Beals spreadsheet so check the Beals paper statements match the Beals data.

# %%
dfB.loc[(dfB['Item Description'].str.contains("Amount payable"))&(dfB.CumAmount!=0)&(dfB.ReconciledBankAccount==6045)].sort_values(by=['Date'])
# Out:
#           Date          ID  Activity I D        Date Created  \
# 12  2022-04-06  F141214ALH        879859 2022-04-06 12:43:00
# 5   2022-04-07  F101214ALH        880097 2022-04-07 13:08:00
# 56  2022-04-07    F3163FRA        880097 2022-04-07 13:08:00
# 34  2022-04-07    F2171FAW        880097 2022-04-07 13:08:00
# 63  2022-04-07   F71214ALH        880097 2022-04-07 13:08:00
# 40  2022-04-07    F1169FAW        880097 2022-04-07 13:08:00
# 52  2022-04-08      F68ALH        880236 2022-04-08 10:35:00
# 72  2022-04-11    F1171FAW        880467 2022-04-11 12:34:00
# 19  2022-04-12   F61618ALH        880985 2022-04-12 12:13:00
# 44  2022-04-12  SHOP196KIN        880985 2022-04-12 12:13:00
# 23  2022-04-13  F111618ALH        881147 2022-04-13 10:11:00
# 27  2022-04-26    F1321LON        884202 2022-04-26 10:51:00
# 191 2022-05-10  F101214ALH        886961 2022-05-10 11:28:00
# 104 2022-05-10  F101214ALH        886961 2022-05-10 11:28:00
# 194 2022-05-20  F101214ALH        889424 2022-05-20 10:35:00
# 107 2022-05-20  F101214ALH        889424 2022-05-20 10:35:00
# 215 2022-06-01  F101214ALH        891743 2022-06-01 11:01:00
#
#                                       Item Description Document Type  \
# 12   Amount payable to Mr Mathew Tucker - Flat 14, ...     Statement
# 5    Amount payable to Mr Mathew Tucker - Flat 10, ...     Statement
# 56   Amount payable to Mr Mathew Tucker - Flat 3, 1...     Statement
# 34   Amount payable to Mr Mathew Tucker - Flat 2, 1...     Statement
# 63   Amount payable to Mr Mathew Tucker - Flat 7, 1...     Statement
# 40   Amount payable to Mr Mathew Tucker - Flat 1, 1...     Statement
# 52   Amount payable to Mr Mathew Tucker - Flat 6, 8...     Statement
# 72   Amount payable to Mr Mathew Tucker - Flat 1, 1...     Statement
# 19   Amount payable to Mr Mathew Tucker - Flat 6, 1...     Statement
# 44   Amount payable to Mr Mathew Tucker - Shop, 196...     Statement
# 23   Amount payable to Mr Mathew Tucker - Flat 11, ...     Statement
# 27   Amount payable to Mr Mathew Tucker - Flat 1, 3...     Statement
# 191  Amount payable to Mr Mathew Tucker - Flat 10, ...     Statement
# 104  Amount payable to Mr Mathew Tucker - Flat 10, ...     Statement
# 194  Amount payable to Mr Mathew Tucker - Flat 10, ...     Statement
# 107  Amount payable to Mr Mathew Tucker - Flat 10, ...     Statement
# 215  Amount payable to Mr Mathew Tucker - Flat 10, ...     Statement
#
#      Document Number  Debit Amount  Credit Amount ID Check  Amount  CumAmount  \
# 12            261097        452.00            0.0       PM  452.00      -6.00
# 5             261177        205.70            0.0       PM  205.70      -6.00
# 56            261182        151.74            0.0       PM  151.74      -6.00
# 34            261181        416.76            0.0       PM  416.76      -6.00
# 63            261185        206.15            0.0       PM  206.15      -6.00
# 40            261176        420.96            0.0       PM  420.96      -6.00
# 52            261233        452.00            0.0       PM  452.00      -6.00
# 72            261295        635.20            0.0       PM  635.20      -6.00
# 19            261680        416.75            0.0       PM  416.75      -6.00
# 44            261684        314.60            0.0       PM  314.60      -6.00
# 23            261764        497.80            0.0       PM  497.80      -6.00
# 27            262990        446.00            0.0       PM  446.00     -12.00
# 191           264087        240.96            0.0       PM  240.96     240.96
# 104           264087        240.96            0.0       PM  240.96    -246.96
# 194           265270        175.80            0.0       PM  175.80     175.80
# 107           265270        175.80            0.0       PM  175.80    -175.80
# 215           266242        276.20            0.0       PM  276.20       6.00
#
#      ReconciledBank  ReconciledBankAccount
# 12              1.0                 6045.0
# 5               1.0                 6045.0
# 56              1.0                 6045.0
# 34              1.0                 6045.0
# 63              1.0                 6045.0
# 40              1.0                 6045.0
# 52              1.0                 6045.0
# 72              1.0                 6045.0
# 19              1.0                 6045.0
# 44              1.0                 6045.0
# 23              1.0                 6045.0
# 27              1.0                 6045.0
# 191             1.0                 6045.0
# 104             1.0                 6045.0
# 194             1.0                 6045.0
# 107             1.0                 6045.0
# 215             1.0                 6045.0

# %% [markdown]
# **** It looks like Flat 10 12-14 went wrong somewhere ****
# - I checked this and the problem is things are a bit in the wrong order in Beals transactions files - it balances out to 0 in the end

# %%
dfB['Amount'].loc[(dfB['Item Description'].str.contains("Amount payable"))&(dfB.CumAmount!=0)&(dfB.ReconciledBankAccount==6045)].sum()
# Out:
# 5725.38

# %%
# Output to file
#dfB.loc[(dfB['Item Description'].str.contains("Amount payable"))&(dfB.CumAmount!=0)&(dfB.ReconciledBankAccount==6045)].sort_values(by=['Date']).to_excel(path+'6045_prevyr.xlsx',sheet_name='6045', index=False)

# %%
dfB.loc[(dfB['Item Description'].str.contains("Amount payable"))&(dfB.CumAmount!=0)&(dfB.ReconciledBankAccount==3072)].sort_values(by=['Date'])
# Out:
#          Date          ID  Activity I D        Date Created  \
# 93 2022-04-07  F121618ALH        880097 2022-04-07 13:08:00
# 89 2022-04-07  F161214ALH        880097 2022-04-07 13:08:00
# 80 2022-04-07   F51214ALH        880097 2022-04-07 13:08:00
#
#                                      Item Description Document Type  \
# 93  Amount payable to Ms Ivana Valentino - Flat 12...     Statement
# 89  Amount payable to Ms Ivana Valentino - Flat 16...     Statement
# 80  Amount payable to Ms Ivana Valentino - Flat 5,...     Statement
#
#     Document Number  Debit Amount  Credit Amount ID Check  Amount  CumAmount  \
# 93           261178        136.27            0.0       PM  136.27       -6.0
# 89           261179        422.29            0.0       PM  422.29       -6.0
# 80           261184        200.06            0.0       PM  200.06       -6.0
#
#     ReconciledBank  ReconciledBankAccount
# 93             1.0                 3072.0
# 89             1.0                 3072.0
# 80             1.0                 3072.0

# %%
dfB['Amount'].loc[(dfB['Item Description'].str.contains("Amount payable"))&(dfB.CumAmount!=0)&(dfB.ReconciledBankAccount==3072)].sum()
# Out:
# 758.6200000000001

# %%
# Output to file
#dfB.loc[(dfB['Item Description'].str.contains("Amount payable"))&(dfB.CumAmount!=0)&(dfB.ReconciledBankAccount==3072)].sort_values(by=['Date']).to_excel(path+'3072_prevyr.xlsx',sheet_name='3072', index=False)

# %% [markdown]
# #### Payments carried forward to next year
# - Often the records in the middle of the year are a result of Beals charging Legal & Compliance fees for flats which we took over after the tenant moved out

# %%
dfB.loc[(dfB.ReconciledBank==0)&(dfB.ReconciledBankAccount==6045)].sort_values(by=['ID','Date'])
# Out:
#           Date          ID  Activity I D        Date Created  \
# 390 2022-07-28     196AKIN        903686 2022-07-28 00:32:00
# 350 2022-07-28  F101214ALH        903686 2022-07-28 00:32:00
# 365 2022-07-28  F111618ALH        903686 2022-07-28 00:32:00
# 382 2022-07-28    F1169FAW        903686 2022-07-28 00:32:00
# 419 2022-07-28    F1171FAW        903686 2022-07-28 00:32:00
# 369 2022-07-28    F1321LON        903686 2022-07-28 00:32:00
# 354 2022-07-28  F141214ALH        903686 2022-07-28 00:32:00
# 376 2022-07-28    F2171FAW        903686 2022-07-28 00:32:00
# 406 2022-07-28    F3163FRA        903686 2022-07-28 00:32:00
# 361 2022-07-28   F61618ALH        903686 2022-07-28 00:32:00
# 396 2022-07-28      F68ALH        903686 2022-07-28 00:32:00
# 397 2022-07-28      F68ALH        903826 2022-07-28 11:26:00
# 398 2022-07-28      F68ALH        903826 2022-07-28 11:26:00
# 399 2022-07-28      F68ALH        903833 2022-07-28 11:32:00
# 413 2022-07-28   F71214ALH        903686 2022-07-28 00:32:00
# 386 2022-07-28  SHOP196KIN        903686 2022-07-28 00:32:00
#
#                                       Item Description Document Type  \
# 390  Legislation & Compliance  - 196a Kingston Road...       Invoice
# 350  Legislation & Compliance  - Flat 10, 12-14 Alh...       Invoice
# 365  Legislation & Compliance  - Flat 11, 16-18 Alh...       Invoice
# 382  Legislation & Compliance  - Flat 1, 169 Fawcet...       Invoice
# 419  Legislation & Compliance  - Flat 1, 171 Fawcet...       Invoice
# 369  Legislation & Compliance  - Flat 1, 321 London...       Invoice
# 354  Legislation & Compliance  - Flat 14, 12-14 Alh...       Invoice
# 376  Legislation & Compliance  - Flat 2, 171 Fawcet...       Invoice
# 406  Legislation & Compliance  - Flat 3, 163 Fratto...       Invoice
# 361  Legislation & Compliance  - Flat 6, 16-18 Alha...       Invoice
# 396  Legislation & Compliance  - Flat 6, 8 Alhambra...       Invoice
# 397  Rent for period 08/07/2022 - 07/08/2022 from M...           NaN
# 398  Management Fee at 7% - Flat 6, 8 Alhambra Road...       Invoice
# 399  Amount payable to Mr Mathew Tucker - Flat 6, 8...     Statement
# 413  Legislation & Compliance  - Flat 7, 12-14 Alha...       Invoice
# 386  Legislation & Compliance  - Shop, 196 Kingston...       Invoice
#
#      Document Number  Debit Amount  Credit Amount ID Check  Amount  CumAmount  \
# 390           360779          6.00           0.00       EX    6.00       6.00
# 350           360703          6.00           0.00       EX    6.00       6.00
# 365           360746          6.00           0.00       EX    6.00       6.00
# 382           360761          6.00           0.00       EX    6.00       6.00
# 419           360763          6.00           0.00       EX    6.00       6.00
# 369           360811         12.00           0.00       EX   12.00      12.00
# 354           360708          6.00           0.00       EX    6.00       6.00
# 376           360765          6.00           0.00       EX    6.00       6.00
# 406           360755          6.00           0.00       EX    6.00       6.00
# 361           360753          6.00           0.00       EX    6.00       6.00
# 396           360855          6.00           0.00       EX    6.00       6.00
# 397                0          0.00          58.68       RT  -58.68     -52.68
# 398           360998          4.93           0.00       MF    4.93     -47.75
# 399           271665         47.75           0.00       PM   47.75       0.00
# 413           360715          6.00           0.00       EX    6.00       6.00
# 386           360777          6.00           0.00       EX    6.00       6.00
#
#      ReconciledBank  ReconciledBankAccount
# 390             0.0                 6045.0
# 350             0.0                 6045.0
# 365             0.0                 6045.0
# 382             0.0                 6045.0
# 419             0.0                 6045.0
# 369             0.0                 6045.0
# 354             0.0                 6045.0
# 376             0.0                 6045.0
# 406             0.0                 6045.0
# 361             0.0                 6045.0
# 396             0.0                 6045.0
# 397             0.0                 6045.0
# 398             0.0                 6045.0
# 399             0.0                 6045.0
# 413             0.0                 6045.0
# 386             0.0                 6045.0

# %%
dfB['Amount'].loc[(dfB.ReconciledBank==0)&(dfB.ReconciledBankAccount==6045)].sum()
# Out:
# 78.0

# %%
# Output carried forward to file
dfB.loc[(dfB.ReconciledBank==0)&(dfB.ReconciledBankAccount==6045)].sort_values(by=['Date']).to_excel(path+'6045_carriedfwd.xlsx',sheet_name='6045', index=False)

# %%
dfB.loc[(dfB.ReconciledBank==0)&(dfB.ReconciledBankAccount==3072)].sort_values(by=['ID','Date'])
# Out:
#           Date          ID  Activity I D        Date Created  \
# 426 2022-07-28  F121618ALH        903686 2022-07-28 00:32:00
# 432 2022-07-28  F161214ALH        903686 2022-07-28 00:32:00
# 439 2022-07-28   F51214ALH        903686 2022-07-28 00:32:00
# 443 2022-07-28      F78ALH        903686 2022-07-28 00:32:00
#
#                                       Item Description Document Type  \
# 426  Legislation & Compliance  - Flat 12, 16-18 Alh...       Invoice
# 432  Legislation & Compliance  - Flat 16, 12-14 Alh...       Invoice
# 439  Legislation & Compliance  - Flat 5, 12-14 Alha...       Invoice
# 443  Legislation & Compliance  - Flat 7, 8 Alhambra...       Invoice
#
#      Document Number  Debit Amount  Credit Amount ID Check  Amount  CumAmount  \
# 426           360747           6.0            0.0       EX     6.0        6.0
# 432           360711           6.0            0.0       EX     6.0        6.0
# 439           360714           6.0            0.0       EX     6.0        6.0
# 443           360856           6.0            0.0       EX     6.0        6.0
#
#      ReconciledBank  ReconciledBankAccount
# 426             0.0                 3072.0
# 432             0.0                 3072.0
# 439             0.0                 3072.0
# 443             0.0                 3072.0

# %%
dfB['Amount'].loc[(dfB.ReconciledBank==0)&(dfB.ReconciledBankAccount==3072)].sum()
# Out:
# 24.0

# %%
dfB.loc[(dfB.ReconciledBank==0)&(dfB.ReconciledBankAccount==3072)].sort_values(by=['Date']).to_excel(path+'3072_carriedfwd.xlsx',sheet_name='3072', index=False)

# %% [markdown]
# ### Output files
# - save Bank files with Beals payment reconciliation flag
# - save Beals files with bank reconciliation flag, bank account it was paid into and cumulative amount

# %%
file6=backup_file(path+'6045_categorisedAndBealsReconciled.xlsx')
file3=backup_file(path+'3072_categorisedAndBealsReconciled.xlsx')
fileB=backup_file(path+'beals_bankReconciled.xlsx')
df6.to_excel(file6,sheet_name='6045', index=False)
df3.to_excel(file3,sheet_name='3072', index=False)
dfB.to_excel(fileB,sheet_name='beals', index=False)

# %% [markdown]
# ### Create Beals/Bank reconciliation check
# - this file can be used to check that the bank deposits minus agency fees match the Beals payments

# %%
dfB.rename(columns={'ReconciledBankAccount':'BankAccount'},inplace=True)
dfB.rename(columns={'Item Description':'PostNarrative'},inplace=True)
dfB.rename(columns={'ID':'Property'},inplace=True)

# %%
dfB.loc[(dfB.PostNarrative.str.contains('Rent for period'))&(dfB.BankAccount==6045),'Account']='0001'
dfB.loc[(dfB.PostNarrative.str.contains('Rent for period'))&(dfB.BankAccount==6045),'Account Description']='Rental Income'
dfB.loc[(dfB.PostNarrative.str.contains('Rent for period'))&(dfB.BankAccount==6045),'Category']='RentalIncome'
dfB.loc[(dfB.PostNarrative.str.contains('Rent for period'))&(dfB.BankAccount==3072),'Account']='0002'
dfB.loc[(dfB.PostNarrative.str.contains('Rent for period'))&(dfB.BankAccount==3072),'Account Description']='Rental Income'
dfB.loc[(dfB.PostNarrative.str.contains('Rent for period'))&(dfB.BankAccount==3072),'Category']='RentalIncome'

dfB.loc[(dfB.PostNarrative.str.contains('Legislation & Compliance'))&(dfB.BankAccount==6045),'Account']='1570'
dfB.loc[(dfB.PostNarrative.str.contains('Legislation & Compliance'))&(dfB.BankAccount==6045),'Account Description']='Management Fees'
dfB.loc[(dfB.PostNarrative.str.contains('Legislation & Compliance'))&(dfB.BankAccount==6045),'Category']='AgentFees'
dfB.loc[(dfB.PostNarrative.str.contains('Legislation & Compliance'))&(dfB.BankAccount==3072),'Account']='1570'
dfB.loc[(dfB.PostNarrative.str.contains('Legislation & Compliance'))&(dfB.BankAccount==3072),'Account Description']='Management Fees'
dfB.loc[(dfB.PostNarrative.str.contains('Legislation & Compliance'))&(dfB.BankAccount==3072),'Category']='AgentFees'

dfB.loc[(dfB.PostNarrative.str.contains('Management Fee'))&(dfB.BankAccount==6045),'Account']='1570'
dfB.loc[(dfB.PostNarrative.str.contains('Management Fee'))&(dfB.BankAccount==6045),'Account Description']='Management Fees'
dfB.loc[(dfB.PostNarrative.str.contains('Management Fee'))&(dfB.BankAccount==6045),'Category']='AgentFees'
dfB.loc[(dfB.PostNarrative.str.contains('Management Fee'))&(dfB.BankAccount==3072),'Account']='1570'
dfB.loc[(dfB.PostNarrative.str.contains('Management Fee'))&(dfB.BankAccount==3072),'Account Description']='Management Fees'
dfB.loc[(dfB.PostNarrative.str.contains('Management Fee'))&(dfB.BankAccount==3072),'Category']='AgentFees'

dfB.loc[(dfB.PostNarrative.str.contains('Amount payable'))&(dfB.BankAccount==6045),'Account']='4801'
dfB.loc[(dfB.PostNarrative.str.contains('Amount payable'))&(dfB.BankAccount==6045),'Account Description']='Payment'
dfB.loc[(dfB.PostNarrative.str.contains('Amount payable'))&(dfB.BankAccount==6045),'Category']='Payment'
dfB.loc[(dfB.PostNarrative.str.contains('Amount payable'))&(dfB.BankAccount==3072),'Account']='4801'
dfB.loc[(dfB.PostNarrative.str.contains('Amount payable'))&(dfB.BankAccount==3072),'Account Description']='Payment'
dfB.loc[(dfB.PostNarrative.str.contains('Amount payable'))&(dfB.BankAccount==3072),'Category']='Payment'

dfB.loc[(dfB.PostNarrative.str.contains('Amount payable'))&(dfB.BankAccount==6045),'Account']='4801'
dfB.loc[(dfB.PostNarrative.str.contains('Amount payable'))&(dfB.BankAccount==6045),'Account Description']='Payment'
dfB.loc[(dfB.PostNarrative.str.contains('Amount payable'))&(dfB.BankAccount==6045),'Category']='Payment'
dfB.loc[(dfB.PostNarrative.str.contains('Amount payable'))&(dfB.BankAccount==3072),'Account']='4801'
dfB.loc[(dfB.PostNarrative.str.contains('Amount payable'))&(dfB.BankAccount==3072),'Account Description']='Payment'
dfB.loc[(dfB.PostNarrative.str.contains('Amount payable'))&(dfB.BankAccount==3072),'Category']='Payment'

dfB.loc[(~dfB.PostNarrative.str.contains('Amount payable'))&(~dfB.PostNarrative.str.contains('Rent for period'))&(~dfB.PostNarrative.str.contains('Legislation & Compliance'))&(~dfB.PostNarrative.str.contains('Management Fee'))&(dfB.BankAccount==6045),'Account']='3140'
dfB.loc[(~dfB.PostNarrative.str.contains('Amount payable'))&(~dfB.PostNarrative.str.contains('Rent for period'))&(~dfB.PostNarrative.str.contains('Legislation & Compliance'))&(~dfB.PostNarrative.str.contains('Management Fee'))&(dfB.BankAccount==6045),'Account Description']='Repairs, renewals, maintenance'
dfB.loc[(~dfB.PostNarrative.str.contains('Amount payable'))&(~dfB.PostNarrative.str.contains('Rent for period'))&(~dfB.PostNarrative.str.contains('Legislation & Compliance'))&(~dfB.PostNarrative.str.contains('Management Fee'))&(dfB.BankAccount==6045),'Category']='Maintenance'
dfB.loc[(~dfB.PostNarrative.str.contains('Amount payable'))&(~dfB.PostNarrative.str.contains('Rent for period'))&(~dfB.PostNarrative.str.contains('Legislation & Compliance'))&(~dfB.PostNarrative.str.contains('Management Fee'))&(dfB.BankAccount==3072),'Account']='3140'
dfB.loc[(~dfB.PostNarrative.str.contains('Amount payable'))&(~dfB.PostNarrative.str.contains('Rent for period'))&(~dfB.PostNarrative.str.contains('Legislation & Compliance'))&(~dfB.PostNarrative.str.contains('Management Fee'))&(dfB.BankAccount==3072),'Account Description']='Repairs, renewals, maintenance'
dfB.loc[(~dfB.PostNarrative.str.contains('Amount payable'))&(~dfB.PostNarrative.str.contains('Rent for period'))&(~dfB.PostNarrative.str.contains('Legislation & Compliance'))&(~dfB.PostNarrative.str.contains('Management Fee'))&(dfB.BankAccount==3072),'Category']='Maintenance'

# %%
# Check nothing in Beals remains uncategorised
dfB[dfB.Category.isnull()]
# Out:
#           Date    Property  Activity I D        Date Created  \
# 98  2022-04-28  F161618ALH        884442 2022-04-28 00:32:00
# 209 2022-05-28  F161618ALH        890834 2022-05-28 00:32:00
# 343 2022-06-28  F161618ALH        896912 2022-06-28 00:32:00
# 2   2022-04-28    F1846ALH        884442 2022-04-28 00:32:00
# 101 2022-05-28    F1846ALH        890834 2022-05-28 00:32:00
# 212 2022-06-28    F1846ALH        896912 2022-06-28 00:32:00
# 1   2022-04-28    F1946ALH        884442 2022-04-28 00:32:00
# 100 2022-05-28    F1946ALH        890834 2022-05-28 00:32:00
# 211 2022-06-28    F1946ALH        896912 2022-06-28 00:32:00
# 0   2022-04-28    F2046ALH        884442 2022-04-28 00:32:00
# 99  2022-05-28    F2046ALH        890834 2022-05-28 00:32:00
# 210 2022-06-28    F2046ALH        896912 2022-06-28 00:32:00
# 309 2022-06-28    F2146ALH        896912 2022-06-28 00:32:00
# 331 2022-06-28   F31618ALH        896912 2022-06-28 00:32:00
# 14  2022-04-28   F41214ALH        884442 2022-04-28 00:32:00
# 113 2022-05-28   F41214ALH        890834 2022-05-28 00:32:00
# 227 2022-06-28   F41214ALH        896912 2022-06-28 00:32:00
# 29  2022-04-28    F4321LON        884442 2022-04-28 00:32:00
# 129 2022-05-28    F4321LON        890834 2022-05-28 00:32:00
# 246 2022-06-28    F4321LON        896912 2022-06-28 00:32:00
# 332 2022-06-28   F71618ALH        896912 2022-06-28 00:32:00
# 308 2022-06-28      F88ALH        896912 2022-06-28 00:32:00
#
#                                          PostNarrative Document Type  \
# 98   Legislation & Compliance - Flat 16, 16-18 Alha...       Invoice
# 209  Legislation & Compliance - Flat 16, 16-18 Alha...       Invoice
# 343  Legislation & Compliance - Flat 16, 16-18 Alha...       Invoice
# 2    Legislation & Compliance  - Flat 18, 4-6 Alham...       Invoice
# 101  Legislation & Compliance  - Flat 18, 4-6 Alham...       Invoice
# 212  Legislation & Compliance  - Flat 18, 4-6 Alham...       Invoice
# 1    Legislation & Compliance  - Flat 19, 4-6 Alham...       Invoice
# 100  Legislation & Compliance  - Flat 19, 4-6 Alham...       Invoice
# 211  Legislation & Compliance  - Flat 19, 4-6 Alham...       Invoice
# 0    Legislation & Compliance  - Flat 20, 4-6 Alham...       Invoice
# 99   Legislation & Compliance  - Flat 20, 4-6 Alham...       Invoice
# 210  Legislation & Compliance  - Flat 20, 4-6 Alham...       Invoice
# 309  Legislation & Compliance  - Flat 21, 4-6 Alham...       Invoice
# 331  Legislation & Compliance  - Flat 3, 16-18 Alha...       Invoice
# 14   Legislation & Compliance  - Flat 4, 12-14 Alha...       Invoice
# 113  Legislation & Compliance  - Flat 4, 12-14 Alha...       Invoice
# 227  Legislation & Compliance  - Flat 4, 12-14 Alha...       Invoice
# 29   Legislation & Compliance  - Flat 4, 321 London...       Invoice
# 129  Legislation & Compliance  - Flat 4, 321 London...       Invoice
# 246  Legislation & Compliance  - Flat 4, 321 London...       Invoice
# 332  Legislation & Compliance  - Flat 7, 16-18 Alha...       Invoice
# 308  Legislation & Compliance  - Flat 8, 8 Alhambra...       Invoice
#
#      Document Number  Debit Amount  Credit Amount ID Check  Amount  CumAmount  \
# 98            349086           6.0            0.0       EX     6.0        6.0
# 209           353112           6.0            0.0       EX     6.0       12.0
# 343           356889           6.0            0.0       EX     6.0       18.0
# 2             348968           6.0            0.0       EX     6.0        6.0
# 101           352996           6.0            0.0       EX     6.0       12.0
# 212           356780           6.0            0.0       EX     6.0       18.0
# 1             348970           6.0            0.0       EX     6.0        6.0
# 100           352998           6.0            0.0       EX     6.0       12.0
# 211           356782           6.0            0.0       EX     6.0       18.0
# 0             348971           6.0            0.0       EX     6.0        6.0
# 99            352999           6.0            0.0       EX     6.0       12.0
# 210           356783           6.0            0.0       EX     6.0       18.0
# 309           356784           6.0            0.0       EX     6.0        6.0
# 331           356708           6.0            0.0       EX     6.0        6.0
# 14            348848           6.0            0.0       EX     6.0        6.0
# 113           352878           6.0            0.0       EX     6.0       12.0
# 227           356669           6.0            0.0       EX     6.0       18.0
# 29            348959           6.0            0.0       EX     6.0        6.0
# 129           352987           6.0            0.0       EX     6.0       12.0
# 246           356772           6.0            0.0       EX     6.0       18.0
# 332           356710           6.0            0.0       EX     6.0        6.0
# 308           356818           6.0            0.0       EX     6.0        6.0
#
#      ReconciledBank  BankAccount Account Account Description Category
# 98              0.0          NaN     NaN                 NaN      NaN
# 209             0.0          NaN     NaN                 NaN      NaN
# 343             0.0          NaN     NaN                 NaN      NaN
# 2               0.0          NaN     NaN                 NaN      NaN
# 101             0.0          NaN     NaN                 NaN      NaN
# 212             0.0          NaN     NaN                 NaN      NaN
# 1               0.0          NaN     NaN                 NaN      NaN
# 100             0.0          NaN     NaN                 NaN      NaN
# 211             0.0          NaN     NaN                 NaN      NaN
# 0               0.0          NaN     NaN                 NaN      NaN
# 99              0.0          NaN     NaN                 NaN      NaN
# 210             0.0          NaN     NaN                 NaN      NaN
# 309             0.0          NaN     NaN                 NaN      NaN
# 331             0.0          NaN     NaN                 NaN      NaN
# 14              0.0          NaN     NaN                 NaN      NaN
# 113             0.0          NaN     NaN                 NaN      NaN
# 227             0.0          NaN     NaN                 NaN      NaN
# 29              0.0          NaN     NaN                 NaN      NaN
# 129             0.0          NaN     NaN                 NaN      NaN
# 246             0.0          NaN     NaN                 NaN      NaN
# 332             0.0          NaN     NaN                 NaN      NaN
# 308             0.0          NaN     NaN                 NaN      NaN

# %%
cols=['BankAccount','Date','Property','PostNarrative','Amount','Account','Account Description','Category']

# %%
dfGr6=dfB.loc[(dfB.PostNarrative.str.contains('Rent for period'))&(dfB.BankAccount==6045)][cols]
dfGr3=dfB.loc[(dfB.PostNarrative.str.contains('Rent for period'))&(dfB.BankAccount==3072)][cols]
dfLc6=dfB.loc[(dfB.PostNarrative.str.contains('Legislation & Compliance'))&(dfB.BankAccount==6045)][cols]
dfLc3=dfB.loc[(dfB.PostNarrative.str.contains('Legislation & Compliance'))&(dfB.BankAccount==3072)][cols]
dfMg6=dfB.loc[(dfB.PostNarrative.str.contains('Management Fee'))&(dfB.BankAccount==6045)][cols]
dfMg3=dfB.loc[(dfB.PostNarrative.str.contains('Management Fee'))&(dfB.BankAccount==3072)][cols]
dfOth6=dfB.loc[(~dfB.PostNarrative.str.contains('Amount payable'))&(~dfB.PostNarrative.str.contains('Rent for period'))&(~dfB.PostNarrative.str.contains('Legislation & Compliance'))&(~dfB.PostNarrative.str.contains('Management Fee'))&(dfB.BankAccount==6045)][cols]
dfOth3=dfB.loc[(~dfB.PostNarrative.str.contains('Amount payable'))&(~dfB.PostNarrative.str.contains('Rent for period'))&(~dfB.PostNarrative.str.contains('Legislation & Compliance'))&(~dfB.PostNarrative.str.contains('Management Fee'))&(dfB.BankAccount==3072)][cols]

# %%
df6.rename(columns={'Account':'BankAccount'},inplace=True)
df6.rename(columns={'Memo':'PostNarrative'},inplace=True)
df6['BankAccount']=6045
df6['Account Description']='Payment'
df6.loc[(df6.Category=='BealsRentalIncome'),'Account']='4801'

df3.rename(columns={'Account':'BankAccount'},inplace=True)
df3.rename(columns={'Memo':'PostNarrative'},inplace=True)
df3['BankAccount']=3072
df3['Account Description']='Payment'
df3.loc[(df6.Category=='BealsRentalIncome'),'Account']='4801'

# %%
dfBk6=df6.loc[(df6.Category=='BealsRentalIncome')][cols]
dfBk3=df3.loc[(df3.Category=='BealsRentalIncome')][cols]

# %%
dfAll6=pd.concat([dfGr6,dfLc6,dfMg6,dfBk6,dfOth6]).sort_values(by=['Property','Date'])
dfAll6.reset_index(drop=True,inplace=True)
dfAll3=pd.concat([dfGr3,dfLc3,dfMg3,dfBk3,dfOth3]).sort_values(by=['Property','Date'])
dfAll3.reset_index(drop=True,inplace=True)

# %%
journals=path + 'journals\\'

beals_output_file=backup_file(journals + '3.6.AgentFeesRentalIncomeBankings_Beals_6045.xlsx')
writer = pd.ExcelWriter(beals_output_file, engine='xlsxwriter',datetime_format='dd/mm/yyyy')
dfGr6.to_excel(writer,sheet_name='GrossRent', index=False)
dfLc6.to_excel(writer,sheet_name='Legal', index=False)
dfMg6.to_excel(writer,sheet_name='MgtFee', index=False)
dfOth6.to_excel(writer,sheet_name='Other', index=False)
dfBk6.to_excel(writer,sheet_name='Bank', index=False)
dfAll6.to_excel(writer,sheet_name='All', index=False)
writer.save()

beals_output_file=backup_file(journals + '3.6.AgentFeesRentalIncomeBankings_Beals_3072.xlsx')
writer = pd.ExcelWriter(beals_output_file, engine='xlsxwriter',datetime_format='dd/mm/yyyy')
dfGr3.to_excel(writer,sheet_name='GrossRent', index=False)
dfLc3.to_excel(writer,sheet_name='Legal', index=False)
dfMg3.to_excel(writer,sheet_name='MgtFee', index=False)
dfOth3.to_excel(writer,sheet_name='Other', index=False)
dfBk3.to_excel(writer,sheet_name='Bank', index=False)
dfAll3.to_excel(writer,sheet_name='All', index=False)
writer.save()
